# %%
# !pip install pandas pymongo
# Out:
# Requirement already satisfied: pandas in c:\users\gpier\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: pymongo in c:\users\gpier\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gpier\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gpier\anaconda3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\gpier\anaconda3\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gpier\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\gpier\anaconda3\lib\site-packages (from pymongo) (2.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\gpier\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import sqlite3
import pandas
import pymongo

# Connection 
URL = "mongodb+srv://mongo_user:wb6xlTxueSQ9KU00@cluster-but-sd.8m2t0.mongodb.net/?retryWrites=true&w=majority&appName=cluster-but-sd"
client = pymongo.MongoClient(URL)
db = client.SAE

# Création de la connexion 
conn = sqlite3.connect("ClassicModel.sqlite")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\gpier\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gpier\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gpier\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\gpier\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\gpier\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gpier\AppData\Local\Temp\ipykernel_17992\3589859817.py", line 2, in <module>
#     import pandas
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\gpier\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\gpier\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gpier\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gpier\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\gpier\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\gpier\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\gpier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gpier\AppData\Local\Temp\ipykernel_17992\3589859817.py", line 2, in <module>
#     import pandas
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\gpier\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\gpier\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\gpier\anaconda3\lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
# Requêtes SQL pour récuperer les données de chaque table
products = pandas.read_sql_query(
    """
    SELECT *
    from Products;
    """,
    conn
)

customers = pandas.read_sql_query(
    """
    SELECT *
    from Customers;
    """,
    conn
)

offices = pandas.read_sql_query(
    """
    SELECT *
    from Offices;
    """,
    conn
)

# ========================================================================================

payments = pandas.read_sql_query(
    """
    SELECT *
    from Payments;
    """,
    conn
)

orders = pandas.read_sql_query(
    """
    SELECT *
    from Orders;
    """,
    conn
)

employees = pandas.read_sql_query(
    """
    SELECT *
    from Employees;
    """,
    conn
)

# ========================================================================================

orderdetails = pandas.read_sql_query(
    """
    SELECT *
    from OrderDetails;
    """,
    conn
)

# %% [markdown]
# # Visualiser les résultats des requêtes SQL

# %%
products.to_dict(orient = "records") #Extraction en documents de products
customers.to_dict(orient = "records") #Extraction en documents de customers
offices.to_dict(orient = "records") #Extraction en documents de offices
# Out:
# [{'officeCode': '1.0',
#   'city': 'San Francisco',
#   'phone': '+1 650 219 4782',
#   'addressLine1': '100 Market Street',
#   'addressLine2': 'Suite 300',
#   'state': 'CA',
#   'country': 'USA',
#   'postalCode': '94080',
#   'territory': None},
#  {'officeCode': '2.0',
#   'city': 'Boston',
#   'phone': '+1 215 837 0825',
#   'addressLine1': '1550 Court Place',
#   'addressLine2': 'Suite 102',
#   'state': 'MA',
#   'country': 'USA',
#   'postalCode': '02107',
#   'territory': None},
#  {'officeCode': '3.0',
#   'city': 'NYC',
#   'phone': '+1 212 555 3000',
#   'addressLine1': '523 East 53rd Street',
#   'addressLine2': 'apt. 5A',
#   'state': 'NY',
#   'country': 'USA',
#   'postalCode': '10022',
#   'territory': None},
#  {'officeCode': '4.0',
#   'city': 'Paris',
#   'phone': '+33 14 723 4404',
#   'addressLine1': "43 Rue Jouffroy D'abbans",
#   'addressLine2': 'NULL',
#   'state': None,
#   'country': 'France',
#   'postalCode': '75017',
#   'territory': 'EMEA'},
#  {'officeCode': '5.0',
#   'city': 'Tokyo',
#   'phone': '+81 33 224 5000',
#   'addressLine1': '4-1 Kioicho',
#   'addressLine2': 'NULL',
#   'state': 'Chiyoda-Ku',
#   'country': 'Japan',
#   'postalCode': '102-8578',
#   'territory': 'Japan'},
#  {'officeCode': '6.0',
#   'city': 'Sydney',
#   'phone': '+61 2 9264 2451',
#   'addressLine1': '5-11 Wentworth Avenue',
#   'addressLine2': 'Floor #2',
#   'state': 'NULL',
#   'country': 'Australia',
#   'postalCode': 'NSW 2010',
#   'territory': 'APAC'},
#  {'officeCode': '7.0',
#   'city': 'London',
#   'phone': '+44 20 7877 2041',
#   'addressLine1': '25 Old Broad Street',
#   'addressLine2': 'Level 7',
#   'state': 'NULL',
#   'country': 'UK',
#   'postalCode': 'EC2N 1HN',
#   'territory': 'EMEA'}]

# %% [markdown]
# # Imbriquer nos extractions de table pour créer la collection Customers

# %%
orders = orders.assign(
OrderDetails = [list(orderdetails.query("orderNumber == @id").drop(columns=["orderNumber"]).to_dict(orient="records")) if id in list(orderdetails.orderNumber) else None for id in orders.orderNumber])

customers = customers.assign(
             Payments = [list(payments.query("customerNumber == @id").drop(columns=["customerNumber"]).to_dict(orient="records")) if id in list(payments.customerNumber) else None for id in customers.customerNumber],
             Orders = [list(orders.query("customerNumber == @id").drop(columns=["customerNumber"]).to_dict(orient="records")) if id in list(orders.customerNumber) else None for id in customers.customerNumber])

# %% [markdown]
# # Visualisation du résultat pour s'assurer que tout a bien été récupéré

# %%
customers.to_dict(orient = "records") #Extraction en documents de customers
# Out:
# [{'customerNumber': 103,
#   'customerName': 'Atelier graphique',
#   'contactLastName': 'Schmitt',
#   'contactFirstName': 'Carine',
#   'phone': '40.32.2555',
#   'addressLine1': '54, rue Royale',
#   'addressLine2': 'NULL',
#   'city': 'Nantes',
#   'state': 'NULL',
#   'postalCode': '44000',
#   'country': 'France',
#   'salesRepEmployeeNumber': 1370,
#   'creditLimit': 21000.0,
#   'Payments': [{'checkNumber': 'HQ336336',
#     'paymentDate': '2004/10/19 0:00:00',
#     'amount': 5307.98},
#    {'checkNumber': 'JM555205',
#     'paymentDate': '2003/6/5 0:00:00',
#     'amount': 16560.3},
#    {'checkNumber': 'OM314933',
#     'paymentDate': '2004/12/18 0:00:00',
#     'amount': 2311.68}],
#   'Orders': [{'orderNumber': 10123,
#     'orderDate': '2003/5/20 0:00:00',
#     'requiredDate': '2003/5/29 0:00:00',
#     'shippedDate': '2003/5/22 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1589',
#       'quantityOrdered': 26,
#       'priceEach': 118.22,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_2870',
#       'quantityOrdered': 46,
#       'priceEach': 112.2,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_3685',
#       'quantityOrdered': 34,
#       'priceEach': 156.82,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_1628',
#       'quantityOrdered': 50,
#       'priceEach': 59.87,
#       'orderLineNumber': 1}]},
#    {'orderNumber': 10298,
#     'orderDate': '2004/9/27 0:00:00',
#     'requiredDate': '2004/10/5 0:00:00',
#     'shippedDate': '2004/10/1 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_2016',
#       'quantityOrdered': 39,
#       'priceEach': 96.34,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_2625',
#       'quantityOrdered': 32,
#       'priceEach': 48.46,
#       'orderLineNumber': 2}]},
#    {'orderNumber': 10345,
#     'orderDate': '2004/11/25 0:00:00',
#     'requiredDate': '2004/12/1 0:00:00',
#     'shippedDate': '2004/11/26 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S24_2022',
#       'quantityOrdered': 43,
#       'priceEach': 53.76,
#       'orderLineNumber': 1}]}]},
#  {'customerNumber': 112,
#   'customerName': 'Signal Gift Stores',
#   'contactLastName': 'King',
#   'contactFirstName': 'Sue',
#   'phone': '7025551838',
#   'addressLine1': '8489 Strong St.',
#   'addressLine2': 'NULL',
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'postalCode': '83030',
#   'country': 'USA',
#   'salesRepEmployeeNumber': 1166,
#   'creditLimit': 71800.0,
#   'Payments': [{'checkNumber': 'BO864823',
#     'paymentDate': '2004/12/17 0:00:00',
#     'amount': 14449.61},
#    {'checkNumber': 'HQ55022',
#     'paymentDate': '2003/6/6 0:00:00',
#     'amount': 33847.62},
#    {'checkNumber': 'ND748579',
#     'paymentDate': '2004/8/20 0:00:00',
#     'amount': 34453.85}],
#   'Orders': [{'orderNumber': 10124,
#     'orderDate': '2003/5/21 0:00:00',
#     'requiredDate': '2003/5/29 0:00:00',
#     'shippedDate': '2003/5/25 0:00:00',
#     'status': 'Shipped',
#     'comments': 'Customer very concerned about the exact color of the models. There is high risk that he may dispute the order because there is a slight color mismatch',
#     'OrderDetails': [{'productCode': 'S18_1749',
#       'quantityOrdered': 21,
#       'priceEach': 136.0,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_2248',
#       'quantityOrdered': 42,
#       'priceEach': 53.88,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_2325',
#       'quantityOrdered': 42,
#       'priceEach': 105.52,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_4409',
#       'quantityOrdered': 36,
#       'priceEach': 85.59,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_4933',
#       'quantityOrdered': 23,
#       'priceEach': 57.73,
#       'orderLineNumber': 8},
#      {'productCode': 'S24_1046',
#       'quantityOrdered': 22,
#       'priceEach': 77.9,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_1937',
#       'quantityOrdered': 45,
#       'priceEach': 37.84,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_2022',
#       'quantityOrdered': 22,
#       'priceEach': 45.25,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_2766',
#       'quantityOrdered': 32,
#       'priceEach': 72.7,
#       'orderLineNumber': 10},
#      {'productCode': 'S24_2887',
#       'quantityOrdered': 25,
#       'priceEach': 93.95,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_3191',
#       'quantityOrdered': 49,
#       'priceEach': 83.04,
#       'orderLineNumber': 11},
#      {'productCode': 'S24_3432',
#       'quantityOrdered': 43,
#       'priceEach': 121.0,
#       'orderLineNumber': 13},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 46,
#       'priceEach': 33.23,
#       'orderLineNumber': 4}]},
#    {'orderNumber': 10278,
#     'orderDate': '2004/8/6 0:00:00',
#     'requiredDate': '2004/8/16 0:00:00',
#     'shippedDate': '2004/8/9 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1129',
#       'quantityOrdered': 34,
#       'priceEach': 137.29,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_1589',
#       'quantityOrdered': 23,
#       'priceEach': 113.24,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_1889',
#       'quantityOrdered': 29,
#       'priceEach': 90.86,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_1984',
#       'quantityOrdered': 29,
#       'priceEach': 129.45,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_2870',
#       'quantityOrdered': 39,
#       'priceEach': 110.88,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_3232',
#       'quantityOrdered': 42,
#       'priceEach': 152.41,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_3685',
#       'quantityOrdered': 31,
#       'priceEach': 132.8,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_1628',
#       'quantityOrdered': 35,
#       'priceEach': 45.28,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_2972',
#       'quantityOrdered': 31,
#       'priceEach': 38.89,
#       'orderLineNumber': 8},
#      {'productCode': 'S24_3856',
#       'quantityOrdered': 25,
#       'priceEach': 126.39,
#       'orderLineNumber': 9}]},
#    {'orderNumber': 10346,
#     'orderDate': '2004/11/29 0:00:00',
#     'requiredDate': '2004/12/5 0:00:00',
#     'shippedDate': '2004/11/30 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1342',
#       'quantityOrdered': 42,
#       'priceEach': 36.11,
#       'orderLineNumber': 3},
#      {'productCode': 'S24_2766',
#       'quantityOrdered': 25,
#       'priceEach': 115.07,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_2887',
#       'quantityOrdered': 24,
#       'priceEach': 87.24,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_3191',
#       'quantityOrdered': 24,
#       'priceEach': 138.58,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_3432',
#       'quantityOrdered': 26,
#       'priceEach': 95.88,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 22,
#       'priceEach': 97.44,
#       'orderLineNumber': 4}]}]},
#  {'customerNumber': 114,
#   'customerName': 'Australian Collectors, Co.',
#   'contactLastName': 'Ferguson',
#   'contactFirstName': 'Peter',
#   'phone': '03 9520 4555',
#   'addressLine1': '636 St Kilda Road',
#   'addressLine2': 'Level 3',
#   'city': 'Melbourne',
#   'state': 'Victoria',
#   'postalCode': '3004',
#   'country': 'Australia',
#   'salesRepEmployeeNumber': 1611,
#   'creditLimit': 117300.0,
#   'Payments': [{'checkNumber': 'GG31455',
#     'paymentDate': '2003/5/20 0:00:00',
#     'amount': 50397.66},
#    {'checkNumber': 'MA765515',
#     'paymentDate': '2004/12/15 0:00:00',
#     'amount': 85591.32},
#    {'checkNumber': 'NP603840',
#     'paymentDate': '2003/5/31 0:00:00',
#     'amount': 9738.18},
#    {'checkNumber': 'NR27552',
#     'paymentDate': '2004/3/10 0:00:00',
#     'amount': 49637.57}],
#   'Orders': [{'orderNumber': 10120,
#     'orderDate': '2003/4/29 0:00:00',
#     'requiredDate': '2003/5/8 0:00:00',
#     'shippedDate': '2003/5/1 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_2016',
#       'quantityOrdered': 29,
#       'priceEach': 96.34,
#       'orderLineNumber': 3},
#      {'productCode': 'S10_4698',
#       'quantityOrdered': 46,
#       'priceEach': 201.41,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_2581',
#       'quantityOrdered': 29,
#       'priceEach': 71.81,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_2625',
#       'quantityOrdered': 46,
#       'priceEach': 58.15,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_1578',
#       'quantityOrdered': 35,
#       'priceEach': 98.05,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_1785',
#       'quantityOrdered': 39,
#       'priceEach': 119.27,
#       'orderLineNumber': 10},
#      {'productCode': 'S24_2000',
#       'quantityOrdered': 34,
#       'priceEach': 83.79,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_4278',
#       'quantityOrdered': 29,
#       'priceEach': 85.49,
#       'orderLineNumber': 9},
#      {'productCode': 'S32_1374',
#       'quantityOrdered': 22,
#       'priceEach': 111.88,
#       'orderLineNumber': 6},
#      {'productCode': 'S32_4289',
#       'quantityOrdered': 29,
#       'priceEach': 72.23,
#       'orderLineNumber': 11},
#      {'productCode': 'S50_1341',
#       'quantityOrdered': 49,
#       'priceEach': 50.62,
#       'orderLineNumber': 12},
#      {'productCode': 'S700_1691',
#       'quantityOrdered': 47,
#       'priceEach': 82.21,
#       'orderLineNumber': 13},
#      {'productCode': 'S700_2466',
#       'quantityOrdered': 24,
#       'priceEach': 107.7,
#       'orderLineNumber': 15},
#      {'productCode': 'S700_2834',
#       'quantityOrdered': 24,
#       'priceEach': 142.38,
#       'orderLineNumber': 7},
#      {'productCode': 'S700_3167',
#       'quantityOrdered': 43,
#       'priceEach': 76.0,
#       'orderLineNumber': 14}]},
#    {'orderNumber': 10125,
#     'orderDate': '2003/5/21 0:00:00',
#     'requiredDate': '2003/5/27 0:00:00',
#     'shippedDate': '2003/5/24 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1342',
#       'quantityOrdered': 32,
#       'priceEach': 101.71,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_2795',
#       'quantityOrdered': 34,
#       'priceEach': 190.69,
#       'orderLineNumber': 2}]},
#    {'orderNumber': 10223,
#     'orderDate': '2004/2/20 0:00:00',
#     'requiredDate': '2004/2/29 0:00:00',
#     'shippedDate': '2004/2/24 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1678',
#       'quantityOrdered': 37,
#       'priceEach': 107.18,
#       'orderLineNumber': 1},
#      {'productCode': 'S10_2016',
#       'quantityOrdered': 47,
#       'priceEach': 115.37,
#       'orderLineNumber': 4},
#      {'productCode': 'S10_4698',
#       'quantityOrdered': 49,
#       'priceEach': 199.47,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_2581',
#       'quantityOrdered': 47,
#       'priceEach': 100.53,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_2625',
#       'quantityOrdered': 28,
#       'priceEach': 60.57,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_1578',
#       'quantityOrdered': 32,
#       'priceEach': 91.29,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_1785',
#       'quantityOrdered': 34,
#       'priceEach': 106.14,
#       'orderLineNumber': 11},
#      {'productCode': 'S24_2000',
#       'quantityOrdered': 38,
#       'priceEach': 69.31,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_4278',
#       'quantityOrdered': 23,
#       'priceEach': 74.62,
#       'orderLineNumber': 10},
#      {'productCode': 'S32_1374',
#       'quantityOrdered': 21,
#       'priceEach': 117.87,
#       'orderLineNumber': 7},
#      {'productCode': 'S32_4289',
#       'quantityOrdered': 20,
#       'priceEach': 66.04,
#       'orderLineNumber': 12},
#      {'productCode': 'S50_1341',
#       'quantityOrdered': 41,
#       'priceEach': 46.26,
#       'orderLineNumber': 13},
#      {'productCode': 'S700_1691',
#       'quantityOrdered': 25,
#       'priceEach': 101.39,
#       'orderLineNumber': 14},
#      {'productCode': 'S700_2834',
#       'quantityOrdered': 29,
#       'priceEach': 110.34,
#       'orderLineNumber': 8},
#      {'productCode': 'S700_3167',
#       'quantityOrdered': 26,
#       'priceEach': 67.2,
#       'orderLineNumber': 15}]},
#    {'orderNumber': 10342,
#     'orderDate': '2004/11/24 0:00:00',
#     'requiredDate': '2004/12/1 0:00:00',
#     'shippedDate': '2004/11/29 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1129',
#       'quantityOrdered': 40,
#       'priceEach': 161.36,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_1889',
#       'quantityOrdered': 55,
#       'priceEach': 65.45,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_1984',
#       'quantityOrdered': 22,
#       'priceEach': 143.67,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_3232',
#       'quantityOrdered': 30,
#       'priceEach': 167.65,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_3278',
#       'quantityOrdered': 25,
#       'priceEach': 66.74,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_3482',
#       'quantityOrdered': 55,
#       'priceEach': 119.06,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_3782',
#       'quantityOrdered': 26,
#       'priceEach': 55.95,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_4721',
#       'quantityOrdered': 38,
#       'priceEach': 165.17,
#       'orderLineNumber': 11},
#      {'productCode': 'S24_2972',
#       'quantityOrdered': 39,
#       'priceEach': 40.4,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_3371',
#       'quantityOrdered': 48,
#       'priceEach': 62.45,
#       'orderLineNumber': 10},
#      {'productCode': 'S24_3856',
#       'quantityOrdered': 42,
#       'priceEach': 119.37,
#       'orderLineNumber': 6}]},
#    {'orderNumber': 10347,
#     'orderDate': '2004/11/29 0:00:00',
#     'requiredDate': '2004/12/7 0:00:00',
#     'shippedDate': '2004/11/30 0:00:00',
#     'status': 'Shipped',
#     'comments': 'Can we deliver the new Ford Mustang models by end-of-quarter?',
#     'OrderDetails': [{'productCode': 'S10_1949',
#       'quantityOrdered': 30,
#       'priceEach': 131.49,
#       'orderLineNumber': 1},
#      {'productCode': 'S10_4962',
#       'quantityOrdered': 27,
#       'priceEach': 164.0,
#       'orderLineNumber': 2},
#      {'productCode': 'S12_1666',
#       'quantityOrdered': 29,
#       'priceEach': 123.67,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_1097',
#       'quantityOrdered': 42,
#       'priceEach': 49.6,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_1367',
#       'quantityOrdered': 21,
#       'priceEach': 58.95,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 50,
#       'priceEach': 136.69,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_2795',
#       'quantityOrdered': 21,
#       'priceEach': 229.3,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_2949',
#       'quantityOrdered': 48,
#       'priceEach': 100.3,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_2957',
#       'quantityOrdered': 34,
#       'priceEach': 64.96,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_3136',
#       'quantityOrdered': 45,
#       'priceEach': 109.96,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_3320',
#       'quantityOrdered': 26,
#       'priceEach': 102.19,
#       'orderLineNumber': 12},
#      {'productCode': 'S18_4600',
#       'quantityOrdered': 45,
#       'priceEach': 130.77,
#       'orderLineNumber': 4}]}]},
#  {'customerNumber': 119,
#   'customerName': 'La Rochelle Gifts',
#   'contactLastName': 'Labrune',
#   'contactFirstName': 'Janine',
#   'phone': '40.67.8555',
#   'addressLine1': '67, rue des Cinquante Otages',
#   'addressLine2': 'NULL',
#   'city': 'Nantes',
#   'state': 'NULL',
#   'postalCode': '44000',
#   'country': 'France',
#   'salesRepEmployeeNumber': 1370,
#   'creditLimit': 118200.0,
#   'Payments': [{'checkNumber': 'DB933704',
#     'paymentDate': '2004/11/14 0:00:00',
#     'amount': 20719.91},
#    {'checkNumber': 'LN373447',
#     'paymentDate': '2004/8/8 0:00:00',
#     'amount': 56002.9},
#    {'checkNumber': 'NG94694',
#     'paymentDate': '2005/2/22 0:00:00',
#     'amount': 59617.44}],
#   'Orders': [{'orderNumber': 10275,
#     'orderDate': '2004/7/23 0:00:00',
#     'requiredDate': '2004/8/2 0:00:00',
#     'shippedDate': '2004/7/29 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1678',
#       'quantityOrdered': 45,
#       'priceEach': 92.83,
#       'orderLineNumber': 1},
#      {'productCode': 'S10_2016',
#       'quantityOrdered': 22,
#       'priceEach': 132.02,
#       'orderLineNumber': 4},
#      {'productCode': 'S10_4698',
#       'quantityOrdered': 36,
#       'priceEach': 191.72,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_2581',
#       'quantityOrdered': 35,
#       'priceEach': 90.39,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_2625',
#       'quantityOrdered': 37,
#       'priceEach': 63.6,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_1578',
#       'quantityOrdered': 21,
#       'priceEach': 102.56,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_1785',
#       'quantityOrdered': 25,
#       'priceEach': 95.2,
#       'orderLineNumber': 11},
#      {'productCode': 'S24_2000',
#       'quantityOrdered': 30,
#       'priceEach': 79.98,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_3949',
#       'quantityOrdered': 41,
#       'priceEach': 81.89,
#       'orderLineNumber': 18},
#      {'productCode': 'S24_4278',
#       'quantityOrdered': 27,
#       'priceEach': 62.31,
#       'orderLineNumber': 10},
#      {'productCode': 'S32_1374',
#       'quantityOrdered': 23,
#       'priceEach': 81.91,
#       'orderLineNumber': 7},
#      {'productCode': 'S32_4289',
#       'quantityOrdered': 28,
#       'priceEach': 63.97,
#       'orderLineNumber': 12},
#      {'productCode': 'S50_1341',
#       'quantityOrdered': 38,
#       'priceEach': 45.39,
#       'orderLineNumber': 13},
#      {'productCode': 'S700_1691',
#       'quantityOrdered': 32,
#       'priceEach': 89.51,
#       'orderLineNumber': 14},
#      {'productCode': 'S700_2466',
#       'quantityOrdered': 39,
#       'priceEach': 114.68,
#       'orderLineNumber': 16},
#      {'productCode': 'S700_2834',
#       'quantityOrdered': 48,
#       'priceEach': 132.89,
#       'orderLineNumber': 8},
#      {'productCode': 'S700_3167',
#       'quantityOrdered': 43,
#       'priceEach': 73.6,
#       'orderLineNumber': 15},
#      {'productCode': 'S700_4002',
#       'quantityOrdered': 31,
#       'priceEach': 72.55,
#       'orderLineNumber': 17}]},
#    {'orderNumber': 10315,
#     'orderDate': '2004/10/29 0:00:00',
#     'requiredDate': '2004/11/8 0:00:00',
#     'shippedDate': '2004/10/30 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_4522',
#       'quantityOrdered': 36,
#       'priceEach': 100.06,
#       'orderLineNumber': 7},
#      {'productCode': 'S24_2011',
#       'quantityOrdered': 35,
#       'priceEach': 120.43,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_3151',
#       'quantityOrdered': 24,
#       'priceEach': 86.74,
#       'orderLineNumber': 1},
#      {'productCode': 'S700_1138',
#       'quantityOrdered': 41,
#       'priceEach': 62.0,
#       'orderLineNumber': 2},
#      {'productCode': 'S700_3505',
#       'quantityOrdered': 31,
#       'priceEach': 86.15,
#       'orderLineNumber': 3},
#      {'productCode': 'S700_3962',
#       'quantityOrdered': 37,
#       'priceEach': 91.37,
#       'orderLineNumber': 4},
#      {'productCode': 'S72_3212',
#       'quantityOrdered': 40,
#       'priceEach': 55.69,
#       'orderLineNumber': 5}]},
#    {'orderNumber': 10375,
#     'orderDate': '2005/2/3 0:00:00',
#     'requiredDate': '2005/2/10 0:00:00',
#     'shippedDate': '2005/2/6 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1678',
#       'quantityOrdered': 21,
#       'priceEach': 34.91,
#       'orderLineNumber': 12},
#      {'productCode': 'S12_1099',
#       'quantityOrdered': 45,
#       'priceEach': 76.0,
#       'orderLineNumber': 7},
#      {'productCode': 'S12_2823',
#       'quantityOrdered': 49,
#       'priceEach': 78.92,
#       'orderLineNumber': 13},
#      {'productCode': 'S24_2000',
#       'quantityOrdered': 23,
#       'priceEach': 106.23,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_2360',
#       'quantityOrdered': 20,
#       'priceEach': 102.3,
#       'orderLineNumber': 14},
#      {'productCode': 'S24_4278',
#       'quantityOrdered': 43,
#       'priceEach': 233.48,
#       'orderLineNumber': 2},
#      {'productCode': 'S32_1374',
#       'quantityOrdered': 37,
#       'priceEach': 171.71,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_4289',
#       'quantityOrdered': 44,
#       'priceEach': 82.26,
#       'orderLineNumber': 4},
#      {'productCode': 'S32_4485',
#       'quantityOrdered': 41,
#       'priceEach': 114.68,
#       'orderLineNumber': 15},
#      {'productCode': 'S50_1341',
#       'quantityOrdered': 49,
#       'priceEach': 65.8,
#       'orderLineNumber': 5},
#      {'productCode': 'S50_4713',
#       'quantityOrdered': 49,
#       'priceEach': 110.34,
#       'orderLineNumber': 8},
#      {'productCode': 'S700_1691',
#       'quantityOrdered': 37,
#       'priceEach': 81.87,
#       'orderLineNumber': 6},
#      {'productCode': 'S700_2466',
#       'quantityOrdered': 33,
#       'priceEach': 116.87,
#       'orderLineNumber': 1},
#      {'productCode': 'S700_2834',
#       'quantityOrdered': 25,
#       'priceEach': 66.73,
#       'orderLineNumber': 10},
#      {'productCode': 'S700_3167',
#       'quantityOrdered': 44,
#       'priceEach': 118.38,
#       'orderLineNumber': 11}]},
#    {'orderNumber': 10425,
#     'orderDate': '2005/5/31 0:00:00',
#     'requiredDate': '2005/6/7 0:00:00',
#     'shippedDate': 'NULL',
#     'status': 'In Process',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_4962',
#       'quantityOrdered': 38,
#       'priceEach': 155.13,
#       'orderLineNumber': 12},
#      {'productCode': 'S12_4473',
#       'quantityOrdered': 33,
#       'priceEach': 142.2,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_2238',
#       'quantityOrdered': 28,
#       'priceEach': 189.93,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_2319',
#       'quantityOrdered': 38,
#       'priceEach': 99.41,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 19,
#       'priceEach': 49.22,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_3232',
#       'quantityOrdered': 28,
#       'priceEach': 135.47,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_4600',
#       'quantityOrdered': 38,
#       'priceEach': 113.82,
#       'orderLineNumber': 13},
#      {'productCode': 'S24_1444',
#       'quantityOrdered': 55,
#       'priceEach': 46.82,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_2300',
#       'quantityOrdered': 49,
#       'priceEach': 112.46,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_2840',
#       'quantityOrdered': 31,
#       'priceEach': 33.24,
#       'orderLineNumber': 5},
#      {'productCode': 'S32_1268',
#       'quantityOrdered': 41,
#       'priceEach': 86.68,
#       'orderLineNumber': 11},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 11,
#       'priceEach': 43.83,
#       'orderLineNumber': 6},
#      {'productCode': 'S50_1392',
#       'quantityOrdered': 18,
#       'priceEach': 105.33,
#       'orderLineNumber': 2}]}]},
#  {'customerNumber': 121,
#   'customerName': 'Baane Mini Imports',
#   'contactLastName': 'Bergulfsen',
#   'contactFirstName': 'Jonas',
#   'phone': '07-98 9555',
#   'addressLine1': 'Erling Skakkes gate 78',
#   'addressLine2': 'NULL',
#   'city': 'Stavern',
#   'state': 'NULL',
#   'postalCode': '4110',
#   'country': 'Norway',
#   'salesRepEmployeeNumber': 1504,
#   'creditLimit': 81700.0,
#   'Payments': [{'checkNumber': 'DB889831',
#     'paymentDate': '2003/2/16 0:00:00',
#     'amount': 54702.0},
#    {'checkNumber': 'FD317790',
#     'paymentDate': '2003/10/28 0:00:00',
#     'amount': 1474.66},
#    {'checkNumber': 'KI831359',
#     'paymentDate': '2004/11/4 0:00:00',
#     'amount': 19769.68},
#    {'checkNumber': 'MA302151',
#     'paymentDate': '2004/11/28 0:00:00',
#     'amount': 40652.85}],
#   'Orders': [{'orderNumber': 10103,
#     'orderDate': '2003/1/29 0:00:00',
#     'requiredDate': '2003/2/7 0:00:00',
#     'shippedDate': '2003/2/2 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1949',
#       'quantityOrdered': 26,
#       'priceEach': 207.87,
#       'orderLineNumber': 11},
#      {'productCode': 'S10_4962',
#       'quantityOrdered': 42,
#       'priceEach': 128.53,
#       'orderLineNumber': 4},
#      {'productCode': 'S12_1666',
#       'quantityOrdered': 27,
#       'priceEach': 125.74,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_1097',
#       'quantityOrdered': 35,
#       'priceEach': 112.0,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 22,
#       'priceEach': 54.09,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_2949',
#       'quantityOrdered': 27,
#       'priceEach': 83.07,
#       'orderLineNumber': 12},
#      {'productCode': 'S18_2957',
#       'quantityOrdered': 35,
#       'priceEach': 57.46,
#       'orderLineNumber': 14},
#      {'productCode': 'S18_3136',
#       'quantityOrdered': 25,
#       'priceEach': 101.58,
#       'orderLineNumber': 13},
#      {'productCode': 'S18_3320',
#       'quantityOrdered': 46,
#       'priceEach': 104.17,
#       'orderLineNumber': 16},
#      {'productCode': 'S18_4600',
#       'quantityOrdered': 36,
#       'priceEach': 117.45,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_4668',
#       'quantityOrdered': 41,
#       'priceEach': 47.29,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_2300',
#       'quantityOrdered': 36,
#       'priceEach': 102.23,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_4258',
#       'quantityOrdered': 25,
#       'priceEach': 114.92,
#       'orderLineNumber': 15},
#      {'productCode': 'S32_1268',
#       'quantityOrdered': 31,
#       'priceEach': 104.01,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_3522',
#       'quantityOrdered': 45,
#       'priceEach': 75.63,
#       'orderLineNumber': 7},
#      {'productCode': 'S700_2824',
#       'quantityOrdered': 42,
#       'priceEach': 106.21,
#       'orderLineNumber': 6}]},
#    {'orderNumber': 10158,
#     'orderDate': '2003/10/10 0:00:00',
#     'requiredDate': '2003/10/18 0:00:00',
#     'shippedDate': '2003/10/15 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S24_2000',
#       'quantityOrdered': 22,
#       'priceEach': 67.03,
#       'orderLineNumber': 1}]},
#    {'orderNumber': 10309,
#     'orderDate': '2004/10/15 0:00:00',
#     'requiredDate': '2004/10/24 0:00:00',
#     'shippedDate': '2004/10/18 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1678',
#       'quantityOrdered': 41,
#       'priceEach': 107.18,
#       'orderLineNumber': 5},
#      {'productCode': 'S12_2823',
#       'quantityOrdered': 26,
#       'priceEach': 179.24,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_1578',
#       'quantityOrdered': 21,
#       'priceEach': 126.22,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_2360',
#       'quantityOrdered': 24,
#       'priceEach': 56.1,
#       'orderLineNumber': 2},
#      {'productCode': 'S32_4485',
#       'quantityOrdered': 50,
#       'priceEach': 84.7,
#       'orderLineNumber': 3},
#      {'productCode': 'S50_4713',
#       'quantityOrdered': 28,
#       'priceEach': 88.68,
#       'orderLineNumber': 1}]},
#    {'orderNumber': 10325,
#     'orderDate': '2004/11/5 0:00:00',
#     'requiredDate': '2004/11/13 0:00:00',
#     'shippedDate': '2004/11/8 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_4757',
#       'quantityOrdered': 47,
#       'priceEach': 64.93,
#       'orderLineNumber': 6},
#      {'productCode': 'S12_1108',
#       'quantityOrdered': 42,
#       'priceEach': 64.0,
#       'orderLineNumber': 8},
#      {'productCode': 'S12_3891',
#       'quantityOrdered': 24,
#       'priceEach': 107.65,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_3140',
#       'quantityOrdered': 24,
#       'priceEach': 69.12,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_4048',
#       'quantityOrdered': 44,
#       'priceEach': 121.04,
#       'orderLineNumber': 5},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 38,
#       'priceEach': 232.74,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_3207',
#       'quantityOrdered': 28,
#       'priceEach': 192.05,
#       'orderLineNumber': 2},
#      {'productCode': 'S50_1392',
#       'quantityOrdered': 38,
#       'priceEach': 136.59,
#       'orderLineNumber': 4},
#      {'productCode': 'S50_1514',
#       'quantityOrdered': 44,
#       'priceEach': 134.84,
#       'orderLineNumber': 7}]}]},
#  {'customerNumber': 124,
#   'customerName': 'Mini Gifts Distributors Ltd.',
#   'contactLastName': 'Nelson',
#   'contactFirstName': 'Valarie',
#   'phone': '4155551450',
#   'addressLine1': '5677 Strong St.',
#   'addressLine2': 'NULL',
#   'city': 'San Rafael',
#   'state': 'CA',
#   'postalCode': '97562',
#   'country': 'USA',
#   'salesRepEmployeeNumber': 1165,
#   'creditLimit': 210500.0,
#   'Payments': [{'checkNumber': 'AE215433',
#     'paymentDate': '2005/2/18 0:00:00',
#     'amount': 51826.36},
#    {'checkNumber': 'AQ50522',
#     'paymentDate': '2005/6/3 0:00:00',
#     'amount': 32194.79},
#    {'checkNumber': 'BG255406',
#     'paymentDate': '2004/8/28 0:00:00',
#     'amount': 93928.73},
#    {'checkNumber': 'CQ287967',
#     'paymentDate': '2003/4/11 0:00:00',
#     'amount': 12398.56},
#    {'checkNumber': 'ET64396',
#     'paymentDate': '2005/4/16 0:00:00',
#     'amount': 121972.78},
#    {'checkNumber': 'HI366474',
#     'paymentDate': '2004/12/27 0:00:00',
#     'amount': 50547.68},
#    {'checkNumber': 'HR86578',
#     'paymentDate': '2004/11/2 0:00:00',
#     'amount': 63075.06},
#    {'checkNumber': 'KI131716',
#     'paymentDate': '2003/8/15 0:00:00',
#     'amount': 122368.67},
#    {'checkNumber': 'LF217299',
#     'paymentDate': '2004/3/26 0:00:00',
#     'amount': 48922.77},
#    {'checkNumber': 'NT141748',
#     'paymentDate': '2003/11/25 0:00:00',
#     'amount': 50360.89}],
#   'Orders': [{'orderNumber': 10113,
#     'orderDate': '2003/3/26 0:00:00',
#     'requiredDate': '2003/4/2 0:00:00',
#     'shippedDate': '2003/3/27 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_1666',
#       'quantityOrdered': 21,
#       'priceEach': 162.64,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_1097',
#       'quantityOrdered': 49,
#       'priceEach': 100.34,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_4668',
#       'quantityOrdered': 50,
#       'priceEach': 49.81,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_3522',
#       'quantityOrdered': 23,
#       'priceEach': 68.52,
#       'orderLineNumber': 1}]},
#    {'orderNumber': 10135,
#     'orderDate': '2003/7/2 0:00:00',
#     'requiredDate': '2003/7/12 0:00:00',
#     'shippedDate': '2003/7/3 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_1099',
#       'quantityOrdered': 42,
#       'priceEach': 190.68,
#       'orderLineNumber': 7},
#      {'productCode': 'S12_3380',
#       'quantityOrdered': 48,
#       'priceEach': 125.66,
#       'orderLineNumber': 5},
#      {'productCode': 'S12_3990',
#       'quantityOrdered': 24,
#       'priceEach': 75.01,
#       'orderLineNumber': 8},
#      {'productCode': 'S12_4675',
#       'quantityOrdered': 29,
#       'priceEach': 97.89,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_1889',
#       'quantityOrdered': 48,
#       'priceEach': 79.31,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_3278',
#       'quantityOrdered': 45,
#       'priceEach': 78.0,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_3482',
#       'quantityOrdered': 42,
#       'priceEach': 129.35,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_3782',
#       'quantityOrdered': 45,
#       'priceEach': 50.36,
#       'orderLineNumber': 13},
#      {'productCode': 'S18_4721',
#       'quantityOrdered': 31,
#       'priceEach': 151.78,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_2360',
#       'quantityOrdered': 29,
#       'priceEach': 61.64,
#       'orderLineNumber': 16},
#      {'productCode': 'S24_2972',
#       'quantityOrdered': 20,
#       'priceEach': 35.87,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_3371',
#       'quantityOrdered': 27,
#       'priceEach': 66.13,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_3856',
#       'quantityOrdered': 47,
#       'priceEach': 134.81,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_4620',
#       'quantityOrdered': 23,
#       'priceEach': 87.31,
#       'orderLineNumber': 11},
#      {'productCode': 'S32_2206',
#       'quantityOrdered': 33,
#       'priceEach': 40.23,
#       'orderLineNumber': 14},
#      {'productCode': 'S32_4485',
#       'quantityOrdered': 30,
#       'priceEach': 89.8,
#       'orderLineNumber': 17},
#      {'productCode': 'S50_4713',
#       'quantityOrdered': 44,
#       'priceEach': 96.0,
#       'orderLineNumber': 15}]},
#    {'orderNumber': 10142,
#     'orderDate': '2003/8/8 0:00:00',
#     'requiredDate': '2003/8/16 0:00:00',
#     'shippedDate': '2003/8/13 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_1108',
#       'quantityOrdered': 33,
#       'priceEach': 243.13,
#       'orderLineNumber': 12},
#      {'productCode': 'S12_3148',
#       'quantityOrdered': 33,
#       'priceEach': 151.08,
#       'orderLineNumber': 13},
#      {'productCode': 'S12_3891',
#       'quantityOrdered': 46,
#       'priceEach': 205.89,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_3140',
#       'quantityOrdered': 47,
#       'priceEach': 128.39,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_3259',
#       'quantityOrdered': 22,
#       'priceEach': 97.81,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_4027',
#       'quantityOrdered': 24,
#       'priceEach': 157.98,
#       'orderLineNumber': 15},
#      {'productCode': 'S18_4522',
#       'quantityOrdered': 24,
#       'priceEach': 70.22,
#       'orderLineNumber': 7},
#      {'productCode': 'S24_2011',
#       'quantityOrdered': 33,
#       'priceEach': 102.0,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_3151',
#       'quantityOrdered': 49,
#       'priceEach': 98.25,
#       'orderLineNumber': 1},
#      {'productCode': 'S32_3207',
#       'quantityOrdered': 42,
#       'priceEach': 74.57,
#       'orderLineNumber': 16},
#      {'productCode': 'S50_1514',
#       'quantityOrdered': 42,
#       'priceEach': 49.79,
#       'orderLineNumber': 14},
#      {'productCode': 'S700_1138',
#       'quantityOrdered': 41,
#       'priceEach': 64.0,
#       'orderLineNumber': 2},
#      {'productCode': 'S700_1938',
#       'quantityOrdered': 43,
#       'priceEach': 84.01,
#       'orderLineNumber': 9},
#      {'productCode': 'S700_3505',
#       'quantityOrdered': 21,
#       'priceEach': 111.19,
#       'orderLineNumber': 3},
#      {'productCode': 'S700_3962',
#       'quantityOrdered': 38,
#       'priceEach': 85.41,
#       'orderLineNumber': 4},
#      {'productCode': 'S72_3212',
#       'quantityOrdered': 39,
#       'priceEach': 44.23,
#       'orderLineNumber': 5}]},
#    {'orderNumber': 10182,
#     'orderDate': '2003/11/12 0:00:00',
#     'requiredDate': '2003/11/21 0:00:00',
#     'shippedDate': '2003/11/18 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1342',
#       'quantityOrdered': 25,
#       'priceEach': 87.33,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_1367',
#       'quantityOrdered': 32,
#       'priceEach': 54.45,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_1749',
#       'quantityOrdered': 44,
#       'priceEach': 171.7,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_2248',
#       'quantityOrdered': 38,
#       'priceEach': 61.15,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_2325',
#       'quantityOrdered': 20,
#       'priceEach': 110.6,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_2795',
#       'quantityOrdered': 21,
#       'priceEach': 145.13,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_3320',
#       'quantityOrdered': 33,
#       'priceEach': 86.31,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_4409',
#       'quantityOrdered': 36,
#       'priceEach': 109.52,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_4933',
#       'quantityOrdered': 44,
#       'priceEach': 69.84,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_1046',
#       'quantityOrdered': 47,
#       'priceEach': 74.22,
#       'orderLineNumber': 16},
#      {'productCode': 'S24_1937',
#       'quantityOrdered': 39,
#       'priceEach': 36.84,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_2022',
#       'quantityOrdered': 31,
#       'priceEach': 36.74,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_2766',
#       'quantityOrdered': 36,
#       'priceEach': 73.6,
#       'orderLineNumber': 14},
#      {'productCode': 'S24_2887',
#       'quantityOrdered': 20,
#       'priceEach': 119.79,
#       'orderLineNumber': 13},
#      {'productCode': 'S24_3191',
#       'quantityOrdered': 33,
#       'priceEach': 94.17,
#       'orderLineNumber': 15},
#      {'productCode': 'S24_3432',
#       'quantityOrdered': 49,
#       'priceEach': 127.43,
#       'orderLineNumber': 17},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 23,
#       'priceEach': 42.26,
#       'orderLineNumber': 8}]},
#    {'orderNumber': 10229,
#     'orderDate': '2004/3/11 0:00:00',
#     'requiredDate': '2004/3/20 0:00:00',
#     'shippedDate': '2004/3/12 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_4962',
#       'quantityOrdered': 50,
#       'priceEach': 128.53,
#       'orderLineNumber': 9},
#      {'productCode': 'S12_1666',
#       'quantityOrdered': 25,
#       'priceEach': 138.04,
#       'orderLineNumber': 13},
#      {'productCode': 'S12_4473',
#       'quantityOrdered': 36,
#       'priceEach': 125.61,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_2319',
#       'quantityOrdered': 26,
#       'priceEach': 144.82,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 28,
#       'priceEach': 59.55,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_3232',
#       'quantityOrdered': 22,
#       'priceEach': 189.66,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_4600',
#       'quantityOrdered': 41,
#       'priceEach': 115.03,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_4668',
#       'quantityOrdered': 39,
#       'priceEach': 40.25,
#       'orderLineNumber': 14},
#      {'productCode': 'S24_2300',
#       'quantityOrdered': 48,
#       'priceEach': 118.84,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_2840',
#       'quantityOrdered': 33,
#       'priceEach': 32.88,
#       'orderLineNumber': 2},
#      {'productCode': 'S32_1268',
#       'quantityOrdered': 25,
#       'priceEach': 111.72,
#       'orderLineNumber': 8},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 23,
#       'priceEach': 54.11,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_3522',
#       'quantityOrdered': 30,
#       'priceEach': 73.04,
#       'orderLineNumber': 12},
#      {'productCode': 'S700_2824',
#       'quantityOrdered': 50,
#       'priceEach': 112.28,
#       'orderLineNumber': 11}]},
#    {'orderNumber': 10271,
#     'orderDate': '2004/7/20 0:00:00',
#     'requiredDate': '2004/7/29 0:00:00',
#     'shippedDate': '2004/7/23 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_4473',
#       'quantityOrdered': 31,
#       'priceEach': 97.17,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_2238',
#       'quantityOrdered': 50,
#       'priceEach': 183.38,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_2319',
#       'quantityOrdered': 50,
#       'priceEach': 101.87,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 25,
#       'priceEach': 69.28,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_3232',
#       'quantityOrdered': 20,
#       'priceEach': 196.43,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_1444',
#       'quantityOrdered': 45,
#       'priceEach': 64.74,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_2300',
#       'quantityOrdered': 43,
#       'priceEach': 130.35,
#       'orderLineNumber': 10},
#      {'productCode': 'S24_2840',
#       'quantityOrdered': 38,
#       'priceEach': 41.72,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_4048',
#       'quantityOrdered': 22,
#       'priceEach': 139.57,
#       'orderLineNumber': 1},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 35,
#       'priceEach': 47.62,
#       'orderLineNumber': 7},
#      {'productCode': 'S50_1392',
#       'quantityOrdered': 34,
#       'priceEach': 98.39,
#       'orderLineNumber': 3}]},
#    {'orderNumber': 10282,
#     'orderDate': '2004/8/20 0:00:00',
#     'requiredDate': '2004/8/26 0:00:00',
#     'shippedDate': '2004/8/22 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_1108',
#       'quantityOrdered': 41,
#       'priceEach': 172.47,
#       'orderLineNumber': 5},
#      {'productCode': 'S12_3148',
#       'quantityOrdered': 27,
#       'priceEach': 161.66,
#       'orderLineNumber': 6},
#      {'productCode': 'S12_3891',
#       'quantityOrdered': 24,
#       'priceEach': 157.45,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_2238',
#       'quantityOrdered': 23,
#       'priceEach': 140.81,
#       'orderLineNumber': 13},
#      {'productCode': 'S18_3140',
#       'quantityOrdered': 43,
#       'priceEach': 155.71,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_3259',
#       'quantityOrdered': 36,
#       'priceEach': 115.97,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_4027',
#       'quantityOrdered': 31,
#       'priceEach': 150.8,
#       'orderLineNumber': 8},
#      {'productCode': 'S24_1444',
#       'quantityOrdered': 29,
#       'priceEach': 46.82,
#       'orderLineNumber': 11},
#      {'productCode': 'S24_4048',
#       'quantityOrdered': 39,
#       'priceEach': 123.01,
#       'orderLineNumber': 10},
#      {'productCode': 'S32_3207',
#       'quantityOrdered': 36,
#       'priceEach': 59.65,
#       'orderLineNumber': 9},
#      {'productCode': 'S50_1392',
#       'quantityOrdered': 38,
#       'priceEach': 113.44,
#       'orderLineNumber': 12},
#      {'productCode': 'S50_1514',
#       'quantityOrdered': 37,
#       'priceEach': 66.78,
#       'orderLineNumber': 7},
#      {'productCode': 'S700_1938',
#       'quantityOrdered': 43,
#       'priceEach': 86.61,
#       'orderLineNumber': 2}]},
#    {'orderNumber': 10312,
#     'orderDate': '2004/10/21 0:00:00',
#     'requiredDate': '2004/10/27 0:00:00',
#     'shippedDate': '2004/10/23 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1949',
#       'quantityOrdered': 48,
#       'priceEach': 242.16,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_1097',
#       'quantityOrdered': 32,
#       'priceEach': 130.67,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_1342',
#       'quantityOrdered': 43,
#       'priceEach': 89.38,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_1367',
#       'quantityOrdered': 25,
#       'priceEach': 44.21,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_1749',
#       'quantityOrdered': 48,
#       'priceEach': 168.3,
#       'orderLineNumber': 17},
#      {'productCode': 'S18_2248',
#       'quantityOrdered': 30,
#       'priceEach': 61.15,
#       'orderLineNumber': 16},
#      {'productCode': 'S18_2325',
#       'quantityOrdered': 31,
#       'priceEach': 152.56,
#       'orderLineNumber': 14},
#      {'productCode': 'S18_2795',
#       'quantityOrdered': 25,
#       'priceEach': 155.25,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_2949',
#       'quantityOrdered': 37,
#       'priceEach': 100.3,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_2957',
#       'quantityOrdered': 35,
#       'priceEach': 53.72,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_3136',
#       'quantityOrdered': 38,
#       'priceEach': 117.29,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_3320',
#       'quantityOrdered': 33,
#       'priceEach': 107.15,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_4668',
#       'quantityOrdered': 39,
#       'priceEach': 56.85,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_1937',
#       'quantityOrdered': 39,
#       'priceEach': 29.54,
#       'orderLineNumber': 13},
#      {'productCode': 'S24_2022',
#       'quantityOrdered': 23,
#       'priceEach': 37.63,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 31,
#       'priceEach': 35.29,
#       'orderLineNumber': 15},
#      {'productCode': 'S24_4258',
#       'quantityOrdered': 44,
#       'priceEach': 111.02,
#       'orderLineNumber': 7}]},
#    {'orderNumber': 10335,
#     'orderDate': '2004/11/19 0:00:00',
#     'requiredDate': '2004/11/29 0:00:00',
#     'shippedDate': '2004/11/23 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S24_2840',
#       'quantityOrdered': 33,
#       'priceEach': 37.13,
#       'orderLineNumber': 2},
#      {'productCode': 'S32_1268',
#       'quantityOrdered': 44,
#       'priceEach': 107.87,
#       'orderLineNumber': 1},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 40,
#       'priceEach': 60.6,
#       'orderLineNumber': 3}]},
#    {'orderNumber': 10357,
#     'orderDate': '2004/12/10 0:00:00',
#     'requiredDate': '2004/12/16 0:00:00',
#     'shippedDate': '2004/12/14 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1949',
#       'quantityOrdered': 32,
#       'priceEach': 177.87,
#       'orderLineNumber': 10},
#      {'productCode': 'S10_4962',
#       'quantityOrdered': 43,
#       'priceEach': 134.44,
#       'orderLineNumber': 9},
#      {'productCode': 'S12_1666',
#       'quantityOrdered': 49,
#       'priceEach': 121.64,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_1097',
#       'quantityOrdered': 39,
#       'priceEach': 98.0,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 41,
#       'priceEach': 61.99,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_2949',
#       'quantityOrdered': 41,
#       'priceEach': 87.13,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_2957',
#       'quantityOrdered': 49,
#       'priceEach': 70.58,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_3136',
#       'quantityOrdered': 44,
#       'priceEach': 117.29,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_3320',
#       'quantityOrdered': 25,
#       'priceEach': 104.17,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_4600',
#       'quantityOrdered': 28,
#       'priceEach': 127.13,
#       'orderLineNumber': 2}]},
#    {'orderNumber': 10368,
#     'orderDate': '2005/1/19 0:00:00',
#     'requiredDate': '2005/1/27 0:00:00',
#     'shippedDate': '2005/1/24 0:00:00',
#     'status': 'Shipped',
#     'comments': 'Can we renegotiate this one?',
#     'OrderDetails': [{'productCode': 'S24_2766',
#       'quantityOrdered': 40,
#       'priceEach': 102.68,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_2887',
#       'quantityOrdered': 31,
#       'priceEach': 136.23,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_3191',
#       'quantityOrdered': 46,
#       'priceEach': 79.62,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_3432',
#       'quantityOrdered': 20,
#       'priceEach': 99.58,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 46,
#       'priceEach': 37.34,
#       'orderLineNumber': 3}]},
#    {'orderNumber': 10371,
#     'orderDate': '2005/1/23 0:00:00',
#     'requiredDate': '2005/2/3 0:00:00',
#     'shippedDate': '2005/1/25 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_1108',
#       'quantityOrdered': 32,
#       'priceEach': 111.27,
#       'orderLineNumber': 6},
#      {'productCode': 'S12_4473',
#       'quantityOrdered': 49,
#       'priceEach': 35.71,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_2238',
#       'quantityOrdered': 25,
#       'priceEach': 104.09,
#       'orderLineNumber': 7},
#      {'productCode': 'S24_1444',
#       'quantityOrdered': 25,
#       'priceEach': 97.27,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_2300',
#       'quantityOrdered': 20,
# ...
#       'priceEach': 182.89,
#       'orderLineNumber': 5}]}]},
#  {'customerNumber': 487,
#   'customerName': 'Signal Collectibles Ltd.',
#   'contactLastName': 'Taylor',
#   'contactFirstName': 'Sue',
#   'phone': '4155554312',
#   'addressLine1': '2793 Furth Circle',
#   'addressLine2': 'NULL',
#   'city': 'Brisbane',
#   'state': 'CA',
#   'postalCode': '94217',
#   'country': 'USA',
#   'salesRepEmployeeNumber': 1165,
#   'creditLimit': 60300.0,
#   'Payments': [{'checkNumber': 'AH612904',
#     'paymentDate': '2003/9/28 0:00:00',
#     'amount': 34100.03},
#    {'checkNumber': 'PT550181',
#     'paymentDate': '2004/2/29 0:00:00',
#     'amount': 16118.48}],
#   'Orders': [{'orderNumber': 10149,
#     'orderDate': '2003/9/12 0:00:00',
#     'requiredDate': '2003/9/18 0:00:00',
#     'shippedDate': '2003/9/17 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1342',
#       'quantityOrdered': 50,
#       'priceEach': 118.15,
#       'orderLineNumber': 4},
#      {'productCode': 'S18_1367',
#       'quantityOrdered': 30,
#       'priceEach': 58.22,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_1749',
#       'quantityOrdered': 34,
#       'priceEach': 158.1,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_2248',
#       'quantityOrdered': 24,
#       'priceEach': 62.36,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_2325',
#       'quantityOrdered': 33,
#       'priceEach': 150.01,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_2795',
#       'quantityOrdered': 23,
#       'priceEach': 183.94,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_3320',
#       'quantityOrdered': 42,
#       'priceEach': 94.25,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_1937',
#       'quantityOrdered': 36,
#       'priceEach': 33.19,
#       'orderLineNumber': 7},
#      {'productCode': 'S24_2022',
#       'quantityOrdered': 49,
#       'priceEach': 49.28,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 26,
#       'priceEach': 38.98,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_4258',
#       'quantityOrdered': 20,
#       'priceEach': 90.57,
#       'orderLineNumber': 1}]},
#    {'orderNumber': 10219,
#     'orderDate': '2004/2/10 0:00:00',
#     'requiredDate': '2004/2/17 0:00:00',
#     'shippedDate': '2004/2/12 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S12_4473',
#       'quantityOrdered': 48,
#       'priceEach': 101.91,
#       'orderLineNumber': 2},
#      {'productCode': 'S18_2238',
#       'quantityOrdered': 43,
#       'priceEach': 196.48,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_2840',
#       'quantityOrdered': 21,
#       'priceEach': 40.31,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 35,
#       'priceEach': 55.19,
#       'orderLineNumber': 4}]}]},
#  {'customerNumber': 489,
#   'customerName': 'Double Decker Gift Stores, Ltd',
#   'contactLastName': 'Hardy',
#   'contactFirstName': 'Thomas',
#   'phone': '(171) 555-7555',
#   'addressLine1': '120 Hanover Sq.',
#   'addressLine2': 'NULL',
#   'city': 'London',
#   'state': 'NULL',
#   'postalCode': 'WA1 1DP',
#   'country': 'UK',
#   'salesRepEmployeeNumber': 1501,
#   'creditLimit': 43300.0,
#   'Payments': [{'checkNumber': 'OC773849',
#     'paymentDate': '2003/12/4 0:00:00',
#     'amount': 27541.82},
#    {'checkNumber': 'PO860906',
#     'paymentDate': '2004/1/31 0:00:00',
#     'amount': 8477.22}],
#   'Orders': [{'orderNumber': 10186,
#     'orderDate': '2003/11/14 0:00:00',
#     'requiredDate': '2003/11/20 0:00:00',
#     'shippedDate': '2003/11/18 0:00:00',
#     'status': 'Shipped',
#     'comments': 'They want to reevaluate their terms agreement with the VP of Sales',
#     'OrderDetails': [{'productCode': 'S10_4757',
#       'quantityOrdered': 26,
#       'priceEach': 148.24,
#       'orderLineNumber': 9},
#      {'productCode': 'S18_1662',
#       'quantityOrdered': 32,
#       'priceEach': 187.65,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_3029',
#       'quantityOrdered': 32,
#       'priceEach': 89.46,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_3856',
#       'quantityOrdered': 46,
#       'priceEach': 106.93,
#       'orderLineNumber': 6},
#      {'productCode': 'S24_2841',
#       'quantityOrdered': 22,
#       'priceEach': 69.2,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_3420',
#       'quantityOrdered': 21,
#       'priceEach': 69.04,
#       'orderLineNumber': 3},
#      {'productCode': 'S24_3816',
#       'quantityOrdered': 36,
#       'priceEach': 85.54,
#       'orderLineNumber': 8},
#      {'productCode': 'S700_2047',
#       'quantityOrdered': 24,
#       'priceEach': 99.57,
#       'orderLineNumber': 5},
#      {'productCode': 'S72_1253',
#       'quantityOrdered': 28,
#       'priceEach': 52.14,
#       'orderLineNumber': 4}]},
#    {'orderNumber': 10213,
#     'orderDate': '2004/1/22 0:00:00',
#     'requiredDate': '2004/1/28 0:00:00',
#     'shippedDate': '2004/1/27 0:00:00',
#     'status': 'Shipped',
#     'comments': 'Difficult to negotiate with customer. We need more marketing materials',
#     'OrderDetails': [{'productCode': 'S18_4409',
#       'quantityOrdered': 38,
#       'priceEach': 94.79,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_4933',
#       'quantityOrdered': 25,
#       'priceEach': 83.39,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_2887',
#       'quantityOrdered': 27,
#       'priceEach': 103.35,
#       'orderLineNumber': 3}]}]},
#  {'customerNumber': 495,
#   'customerName': 'Diecast Collectables',
#   'contactLastName': 'Franco',
#   'contactFirstName': 'Valarie',
#   'phone': '6175552555',
#   'addressLine1': '6251 Ingle Ln.',
#   'addressLine2': 'NULL',
#   'city': 'Boston',
#   'state': 'MA',
#   'postalCode': '51003',
#   'country': 'USA',
#   'salesRepEmployeeNumber': 1188,
#   'creditLimit': 85100.0,
#   'Payments': [{'checkNumber': 'BH167026',
#     'paymentDate': '2003/12/26 0:00:00',
#     'amount': 63730.78},
#    {'checkNumber': 'FN155234',
#     'paymentDate': '2004/5/14 0:00:00',
#     'amount': 7129.0}],
#   'Orders': [{'orderNumber': 10207,
#     'orderDate': '2003/12/9 0:00:00',
#     'requiredDate': '2003/12/17 0:00:00',
#     'shippedDate': '2003/12/11 0:00:00',
#     'status': 'Shipped',
#     'comments': 'Check on availability.',
#     'OrderDetails': [{'productCode': 'S10_4962',
#       'quantityOrdered': 31,
#       'priceEach': 131.49,
#       'orderLineNumber': 15},
#      {'productCode': 'S12_4473',
#       'quantityOrdered': 34,
#       'priceEach': 99.54,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_2238',
#       'quantityOrdered': 44,
#       'priceEach': 160.46,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_2319',
#       'quantityOrdered': 43,
#       'priceEach': 133.78,
#       'orderLineNumber': 10},
#      {'productCode': 'S18_2432',
#       'quantityOrdered': 37,
#       'priceEach': 69.89,
#       'orderLineNumber': 13},
#      {'productCode': 'S18_3232',
#       'quantityOrdered': 25,
#       'priceEach': 157.49,
#       'orderLineNumber': 11},
#      {'productCode': 'S18_4027',
#       'quantityOrdered': 40,
#       'priceEach': 153.67,
#       'orderLineNumber': 1},
#      {'productCode': 'S18_4600',
#       'quantityOrdered': 47,
#       'priceEach': 141.66,
#       'orderLineNumber': 16},
#      {'productCode': 'S24_1444',
#       'quantityOrdered': 49,
#       'priceEach': 46.82,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_2300',
#       'quantityOrdered': 46,
#       'priceEach': 148.24,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_2840',
#       'quantityOrdered': 42,
#       'priceEach': 29.7,
#       'orderLineNumber': 8},
#      {'productCode': 'S24_4048',
#       'quantityOrdered': 28,
#       'priceEach': 106.45,
#       'orderLineNumber': 3},
#      {'productCode': 'S32_1268',
#       'quantityOrdered': 49,
#       'priceEach': 80.9,
#       'orderLineNumber': 14},
#      {'productCode': 'S32_2509',
#       'quantityOrdered': 27,
#       'priceEach': 60.06,
#       'orderLineNumber': 9},
#      {'productCode': 'S32_3207',
#       'quantityOrdered': 45,
#       'priceEach': 56.55,
#       'orderLineNumber': 2},
#      {'productCode': 'S50_1392',
#       'quantityOrdered': 28,
#       'priceEach': 94.92,
#       'orderLineNumber': 5}]},
#    {'orderNumber': 10243,
#     'orderDate': '2004/4/26 0:00:00',
#     'requiredDate': '2004/5/3 0:00:00',
#     'shippedDate': '2004/4/28 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_2325',
#       'quantityOrdered': 47,
#       'priceEach': 130.94,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_1937',
#       'quantityOrdered': 33,
#       'priceEach': 29.54,
#       'orderLineNumber': 1}]}]},
#  {'customerNumber': 496,
#   'customerName': "Kelly's Gift Shop",
#   'contactLastName': 'Snowden',
#   'contactFirstName': 'Tony',
#   'phone': '+64 9 5555500',
#   'addressLine1': "Arenales 1938 3'A'",
#   'addressLine2': 'NULL',
#   'city': 'Auckland',
#   'state': 'NULL',
#   'postalCode': None,
#   'country': 'New Zealand',
#   'salesRepEmployeeNumber': 1612,
#   'creditLimit': 110000.0,
#   'Payments': [{'checkNumber': 'EU531600',
#     'paymentDate': '2005/6/25 0:00:00',
#     'amount': 34332.29},
#    {'checkNumber': 'MB342426',
#     'paymentDate': '2003/7/16 0:00:00',
#     'amount': 37754.33},
#    {'checkNumber': 'MN89921',
#     'paymentDate': '2004/12/31 0:00:00',
#     'amount': 58593.28},
#    {'checkNumber': 'PL783960',
#     'paymentDate': '2003/11/29 0:00:00',
#     'amount': 26421.24}],
#   'Orders': [{'orderNumber': 10138,
#     'orderDate': '2003/7/7 0:00:00',
#     'requiredDate': '2003/7/16 0:00:00',
#     'shippedDate': '2003/7/13 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1749',
#       'quantityOrdered': 33,
#       'priceEach': 161.5,
#       'orderLineNumber': 6},
#      {'productCode': 'S18_2248',
#       'quantityOrdered': 22,
#       'priceEach': 48.43,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_2325',
#       'quantityOrdered': 38,
#       'priceEach': 108.06,
#       'orderLineNumber': 3},
#      {'productCode': 'S18_4409',
#       'quantityOrdered': 47,
#       'priceEach': 100.31,
#       'orderLineNumber': 7},
#      {'productCode': 'S18_4933',
#       'quantityOrdered': 23,
#       'priceEach': 66.99,
#       'orderLineNumber': 8},
#      {'productCode': 'S24_1046',
#       'quantityOrdered': 45,
#       'priceEach': 84.51,
#       'orderLineNumber': 12},
#      {'productCode': 'S24_1937',
#       'quantityOrdered': 22,
#       'priceEach': 29.21,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_2022',
#       'quantityOrdered': 33,
#       'priceEach': 43.01,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_2766',
#       'quantityOrdered': 28,
#       'priceEach': 104.5,
#       'orderLineNumber': 10},
#      {'productCode': 'S24_2887',
#       'quantityOrdered': 30,
#       'priceEach': 138.58,
#       'orderLineNumber': 9},
#      {'productCode': 'S24_3191',
#       'quantityOrdered': 49,
#       'priceEach': 90.75,
#       'orderLineNumber': 11},
#      {'productCode': 'S24_3432',
#       'quantityOrdered': 21,
#       'priceEach': 118.86,
#       'orderLineNumber': 13},
#      {'productCode': 'S24_3969',
#       'quantityOrdered': 29,
#       'priceEach': 38.16,
#       'orderLineNumber': 4}]},
#    {'orderNumber': 10179,
#     'orderDate': '2003/11/11 0:00:00',
#     'requiredDate': '2003/11/17 0:00:00',
#     'shippedDate': '2003/11/13 0:00:00',
#     'status': 'Cancelled',
#     'comments': 'Customer cancelled due to urgent budgeting issues. Must be cautious when dealing with them in the future. Since order shipped already we must discuss who would cover the shipping charges.',
#     'OrderDetails': [{'productCode': 'S18_2581',
#       'quantityOrdered': 24,
#       'priceEach': 78.57,
#       'orderLineNumber': 3},
#      {'productCode': 'S24_1785',
#       'quantityOrdered': 47,
#       'priceEach': 124.74,
#       'orderLineNumber': 5},
#      {'productCode': 'S24_4278',
#       'quantityOrdered': 27,
#       'priceEach': 84.77,
#       'orderLineNumber': 4},
#      {'productCode': 'S32_1374',
#       'quantityOrdered': 45,
#       'priceEach': 119.87,
#       'orderLineNumber': 1},
#      {'productCode': 'S32_4289',
#       'quantityOrdered': 24,
#       'priceEach': 72.23,
#       'orderLineNumber': 6},
#      {'productCode': 'S50_1341',
#       'quantityOrdered': 34,
#       'priceEach': 42.77,
#       'orderLineNumber': 7},
#      {'productCode': 'S700_1691',
#       'quantityOrdered': 23,
#       'priceEach': 107.78,
#       'orderLineNumber': 8},
#      {'productCode': 'S700_2834',
#       'quantityOrdered': 25,
#       'priceEach': 105.6,
#       'orderLineNumber': 2},
#      {'productCode': 'S700_3167',
#       'quantityOrdered': 39,
#       'priceEach': 68.8,
#       'orderLineNumber': 9}]},
#    {'orderNumber': 10360,
#     'orderDate': '2004/12/16 0:00:00',
#     'requiredDate': '2004/12/22 0:00:00',
#     'shippedDate': '2004/12/18 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S18_1662',
#       'quantityOrdered': 50,
#       'priceEach': 58.67,
#       'orderLineNumber': 12},
#      {'productCode': 'S18_2581',
#       'quantityOrdered': 41,
#       'priceEach': 87.48,
#       'orderLineNumber': 13},
#      {'productCode': 'S18_3029',
#       'quantityOrdered': 46,
#       'priceEach': 77.34,
#       'orderLineNumber': 14},
#      {'productCode': 'S18_3140',
#       'quantityOrdered': 29,
#       'priceEach': 175.04,
#       'orderLineNumber': 8},
#      {'productCode': 'S18_3259',
#       'quantityOrdered': 29,
#       'priceEach': 101.38,
#       'orderLineNumber': 18},
#      {'productCode': 'S18_3856',
#       'quantityOrdered': 40,
#       'priceEach': 87.15,
#       'orderLineNumber': 15},
#      {'productCode': 'S18_4522',
#       'quantityOrdered': 40,
#       'priceEach': 86.02,
#       'orderLineNumber': 1},
#      {'productCode': 'S24_1785',
#       'quantityOrdered': 22,
#       'priceEach': 115.2,
#       'orderLineNumber': 17},
#      {'productCode': 'S24_2011',
#       'quantityOrdered': 31,
#       'priceEach': 118.83,
#       'orderLineNumber': 2},
#      {'productCode': 'S24_2841',
#       'quantityOrdered': 49,
#       'priceEach': 56.78,
#       'orderLineNumber': 16},
#      {'productCode': 'S24_3151',
#       'quantityOrdered': 36,
#       'priceEach': 113.95,
#       'orderLineNumber': 3},
#      {'productCode': 'S24_3816',
#       'quantityOrdered': 22,
#       'priceEach': 111.16,
#       'orderLineNumber': 4},
#      {'productCode': 'S700_1138',
#       'quantityOrdered': 32,
#       'priceEach': 100.94,
#       'orderLineNumber': 5},
#      {'productCode': 'S700_1938',
#       'quantityOrdered': 26,
#       'priceEach': 97.38,
#       'orderLineNumber': 6},
#      {'productCode': 'S700_2610',
#       'quantityOrdered': 30,
#       'priceEach': 125.35,
#       'orderLineNumber': 7},
#      {'productCode': 'S700_3505',
#       'quantityOrdered': 35,
#       'priceEach': 65.77,
#       'orderLineNumber': 9},
#      {'productCode': 'S700_3962',
#       'quantityOrdered': 31,
#       'priceEach': 103.56,
#       'orderLineNumber': 10},
#      {'productCode': 'S72_3212',
#       'quantityOrdered': 31,
#       'priceEach': 96.44,
#       'orderLineNumber': 11}]},
#    {'orderNumber': 10399,
#     'orderDate': '2005/4/1 0:00:00',
#     'requiredDate': '2005/4/12 0:00:00',
#     'shippedDate': '2005/4/3 0:00:00',
#     'status': 'Shipped',
#     'comments': 'NULL',
#     'OrderDetails': [{'productCode': 'S10_1678',
#       'quantityOrdered': 40,
#       'priceEach': 113.88,
#       'orderLineNumber': 8},
#      {'productCode': 'S10_2016',
#       'quantityOrdered': 51,
#       'priceEach': 123.7,
#       'orderLineNumber': 7},
#      {'productCode': 'S10_4698',
#       'quantityOrdered': 22,
#       'priceEach': 158.8,
#       'orderLineNumber': 6},
#      {'productCode': 'S12_2823',
#       'quantityOrdered': 29,
#       'priceEach': 164.18,
#       'orderLineNumber': 5},
#      {'productCode': 'S18_2625',
#       'quantityOrdered': 30,
#       'priceEach': 68.44,
#       'orderLineNumber': 4},
#      {'productCode': 'S24_1578',
#       'quantityOrdered': 57,
#       'priceEach': 105.94,
#       'orderLineNumber': 3},
#      {'productCode': 'S24_2000',
#       'quantityOrdered': 58,
#       'priceEach': 89.12,
#       'orderLineNumber': 2},
#      {'productCode': 'S32_1374',
#       'quantityOrdered': 32,
#       'priceEach': 99.89,
#       'orderLineNumber': 1}]}]}]

# %% [markdown]
# # Visualisation des données de la collection Products

# %%
products.to_dict(orient = "records") #Extraction en documents de products
# Out:
# [{'productCode': 'S10_1678',
#   'productName': '1969 Harley Davidson Ultimate Chopper',
#   'productLine': 'Motorcycles',
#   'productScale': '4200.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.',
#   'quantityInStock': 7933,
#   'buyPrice': 48.81,
#   'MSRP': 95.7},
#  {'productCode': 'S10_1949',
#   'productName': '1952 Alpine Renault 1300',
#   'productLine': 'Classic Cars',
#   'productScale': '4200.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 7305,
#   'buyPrice': 98.58,
#   'MSRP': 214.3},
#  {'productCode': 'S10_2016',
#   'productName': '1996 Moto Guzzi 1100i',
#   'productLine': 'Motorcycles',
#   'productScale': '4200.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leather seats, luggage rack, dual exhaust pipes, small saddle bag located on handle bars, two-tone paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.',
#   'quantityInStock': 6625,
#   'buyPrice': 68.99,
#   'MSRP': 118.94},
#  {'productCode': 'S10_4698',
#   'productName': '2003 Harley-Davidson Eagle Drag Bike',
#   'productLine': 'Motorcycles',
#   'productScale': '4200.0',
#   'productVendor': 'Red Start Diecast',
#   'productDescription': 'Model features, official Harley Davidson logos and insignias, detachable rear wheelie bar, heavy diecast metal with resin parts, authentic multi-color tampo-printed graphics, separate engine drive belts, free-turning front fork, rotating tires and rear racing slick, certificate of authenticity, detailed engine, display stand\n, precision diecast replica, baked enamel finish, 1:10 scale model, removable fender, seat and tank cover piece for displaying the superior detail of the v-twin engine',
#   'quantityInStock': 5582,
#   'buyPrice': 91.02,
#   'MSRP': 193.66},
#  {'productCode': 'S10_4757',
#   'productName': '1972 Alfa Romeo GTA',
#   'productLine': 'Classic Cars',
#   'productScale': '4200.0',
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': 'Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 3252,
#   'buyPrice': 85.68,
#   'MSRP': 136.0},
#  {'productCode': 'S10_4962',
#   'productName': '1962 LanciaA Delta 16V',
#   'productLine': 'Classic Cars',
#   'productScale': '4200.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 6791,
#   'buyPrice': 103.42,
#   'MSRP': 147.74},
#  {'productCode': 'S12_1099',
#   'productName': '1968 Ford Mustang',
#   'productLine': 'Classic Cars',
#   'productScale': '4320.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'Hood, doors and trunk all open to reveal highly detailed interior features. Steering wheel actually turns the front wheels. Color dark green.',
#   'quantityInStock': 68,
#   'buyPrice': 95.34,
#   'MSRP': 194.57},
#  {'productCode': 'S12_1108',
#   'productName': '2001 Ferrari Enzo',
#   'productLine': 'Classic Cars',
#   'productScale': '4320.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 3619,
#   'buyPrice': 95.59,
#   'MSRP': 207.8},
#  {'productCode': 'S12_1666',
#   'productName': '1958 Setra Bus',
#   'productLine': 'Trucks and Buses',
#   'productScale': '4320.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': 'Model features 30 windows, skylights & glare resistant glass, working steering system, original logos',
#   'quantityInStock': 1579,
#   'buyPrice': 77.9,
#   'MSRP': 136.67},
#  {'productCode': 'S12_2823',
#   'productName': '2002 Suzuki XREO',
#   'productLine': 'Motorcycles',
#   'productScale': '4320.0',
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'Official logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leather seats, luggage rack, dual exhaust pipes, small saddle bag located on handle bars, two-tone paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.',
#   'quantityInStock': 9997,
#   'buyPrice': 66.27,
#   'MSRP': 150.62},
#  {'productCode': 'S12_3148',
#   'productName': '1969 Corvair Monza',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': '1:18 scale die-cast about 10" long doors open, hood opens, trunk opens and wheels roll',
#   'quantityInStock': 6906,
#   'buyPrice': 89.14,
#   'MSRP': 151.08},
#  {'productCode': 'S12_3380',
#   'productName': '1968 Dodge Charger',
#   'productLine': 'Classic Cars',
#   'productScale': '4320.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': '1:12 scale model of a 1968 Dodge Charger. Hood, doors and trunk all open to reveal highly detailed interior features. Steering wheel actually turns the front wheels. Color black',
#   'quantityInStock': 9123,
#   'buyPrice': 75.16,
#   'MSRP': 117.44},
#  {'productCode': 'S12_3891',
#   'productName': '1969 Ford Falcon',
#   'productLine': 'Classic Cars',
#   'productScale': '4320.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 1049,
#   'buyPrice': 83.05,
#   'MSRP': 173.02},
#  {'productCode': 'S12_3990',
#   'productName': '1970 Plymouth Hemi Cuda',
#   'productLine': 'Classic Cars',
#   'productScale': '4320.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'Very detailed 1970 Plymouth Cuda model in 1:12 scale. The Cuda is generally accepted as one of the fastest original muscle cars from the 1970s. This model is a reproduction of one of the orginal 652 cars built in 1970. Red color.',
#   'quantityInStock': 5663,
#   'buyPrice': 31.92,
#   'MSRP': 79.8},
#  {'productCode': 'S12_4473',
#   'productName': '1957 Chevy Pickup',
#   'productLine': 'Trucks and Buses',
#   'productScale': '4320.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': '1:12 scale die-cast about 20" long Hood opens, Rubber wheels',
#   'quantityInStock': 6125,
#   'buyPrice': 55.7,
#   'MSRP': 118.5},
#  {'productCode': 'S12_4675',
#   'productName': '1969 Dodge Charger',
#   'productLine': 'Classic Cars',
#   'productScale': '4320.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': 'Detailed model of the 1969 Dodge Charger. This model includes finely detailed interior and exterior features. Painted in red and white.',
#   'quantityInStock': 7323,
#   'buyPrice': 58.73,
#   'MSRP': 115.16},
#  {'productCode': 'S18_1097',
#   'productName': '1940 Ford Pickup Truck',
#   'productLine': 'Trucks and Buses',
#   'productScale': '4680.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'This model features soft rubber tires, working steering, rubber mud guards, authentic Ford logos, detailed undercarriage, opening doors and hood,  removable split rear gate, full size spare mounted in bed, detailed interior with opening glove box',
#   'quantityInStock': 2613,
#   'buyPrice': 58.33,
#   'MSRP': 116.67},
#  {'productCode': 'S18_1129',
#   'productName': '1993 Mazda RX-7',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'This model features, opening hood, opening doors, detailed engine, rear spoiler, opening trunk, working steering, tinted windows, baked enamel finish. Color red.',
#   'quantityInStock': 3975,
#   'buyPrice': 83.51,
#   'MSRP': 141.54},
#  {'productCode': 'S18_1342',
#   'productName': '1937 Lincoln Berline',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': 'Features opening engine cover, doors, trunk, and fuel filler cap. Color black',
#   'quantityInStock': 8693,
#   'buyPrice': 60.62,
#   'MSRP': 102.74},
#  {'productCode': 'S18_1367',
#   'productName': '1936 Mercedes-Benz 500K Special Roadster',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'This 1:18 scale replica is constructed of heavy die-cast metal and has all the features of the original: working doors and rumble seat, independent spring suspension, detailed interior, working steering system, and a bifold hood that reveals an engine so accurate that it even includes the wiring. All this is topped off with a baked enamel finish. Color white.',
#   'quantityInStock': 8635,
#   'buyPrice': 24.26,
#   'MSRP': 53.91},
#  {'productCode': 'S18_1589',
#   'productName': '1965 Aston Martin DB5',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'Die-cast model of the silver 1965 Aston Martin DB5 in silver. This model includes full wire wheels and doors that open with fully detailed passenger compartment. In 1:18 scale, this model measures approximately 10 inches/20 cm long.',
#   'quantityInStock': 9042,
#   'buyPrice': 65.96,
#   'MSRP': 124.44},
#  {'productCode': 'S18_1662',
#   'productName': '1980s Black Hawk Helicopter',
#   'productLine': 'Planes',
#   'productScale': '4680.0',
#   'productVendor': 'Red Start Diecast',
#   'productDescription': "1:18 scale replica of actual Army's UH-60L BLACK HAWK Helicopter. 100% hand-assembled. Features rotating rotor blades, propeller blades and rubber wheels.",
#   'quantityInStock': 5330,
#   'buyPrice': 77.27,
#   'MSRP': 157.69},
#  {'productCode': 'S18_1749',
#   'productName': '1917 Grand Touring Sedan',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': 'This 1:18 scale replica of the 1917 Grand Touring car has all the features you would expect from museum quality reproductions: all four doors and bi-fold hood opening, detailed engine and instrument panel, chrome-look trim, and tufted upholstery, all topped off with a factory baked-enamel finish.',
#   'quantityInStock': 2724,
#   'buyPrice': 86.7,
#   'MSRP': 170.0},
#  {'productCode': 'S18_1889',
#   'productName': '1948 Porsche 356-A Roadster',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'This precision die-cast replica features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 8826,
#   'buyPrice': 53.9,
#   'MSRP': 77.0},
#  {'productCode': 'S18_1984',
#   'productName': '1995 Honda Civic',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'This model features, opening hood, opening doors, detailed engine, rear spoiler, opening trunk, working steering, tinted windows, baked enamel finish. Color yellow.',
#   'quantityInStock': 9772,
#   'buyPrice': 93.89,
#   'MSRP': 142.25},
#  {'productCode': 'S18_2238',
#   'productName': '1998 Chrysler Plymouth Prowler',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 4724,
#   'buyPrice': 101.51,
#   'MSRP': 163.73},
#  {'productCode': 'S18_2248',
#   'productName': '1911 Ford Town Car',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': 'Features opening hood, opening doors, opening trunk, wide white wall tires, front door arm rests, working steering system',
#   'quantityInStock': 540,
#   'buyPrice': 33.3,
#   'MSRP': 60.54},
#  {'productCode': 'S18_2319',
#   'productName': '1964 Mercedec Tour Bus',
#   'productLine': 'Trucks and Buses',
#   'productScale': '4680.0',
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'Exact replica. 100+ parts. working steering system, original logos',
#   'quantityInStock': 8258,
#   'buyPrice': 74.86,
#   'MSRP': 122.73},
#  {'productCode': 'S18_2325',
#   'productName': '1932 Model A Ford J-Coupe',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'This model features grille-mounted chrome horn, lift-up louvered hood, fold-down rumble seat, working steering system, chrome-covered spare, opening doors, detailed and wired engine',
#   'quantityInStock': 9354,
#   'buyPrice': 58.48,
#   'MSRP': 127.13},
#  {'productCode': 'S18_2432',
#   'productName': '1926 Ford Fire Engine',
#   'productLine': 'Trucks and Buses',
#   'productScale': '4680.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'Gleaming red handsome appearance. Everything is here the fire hoses, ladder, axes, bells, lanterns, ready to fight any inferno.',
#   'quantityInStock': 2018,
#   'buyPrice': 24.92,
#   'MSRP': 60.77},
#  {'productCode': 'S18_2581',
#   'productName': 'P-51-D Mustang',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'Has retractable wheels and comes with a stand',
#   'quantityInStock': 992,
#   'buyPrice': 49.0,
#   'MSRP': 84.48},
#  {'productCode': 'S18_2625',
#   'productName': '1936 Harley Davidson El Knucklehead',
#   'productLine': 'Motorcycles',
#   'productScale': '4680.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': 'Intricately detailed with chrome accents and trim, official die-struck logos and baked enamel finish.',
#   'quantityInStock': 4357,
#   'buyPrice': 24.23,
#   'MSRP': 60.57},
#  {'productCode': 'S18_2795',
#   'productName': '1928 Mercedes-Benz SSK',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'This 1:18 replica features grille-mounted chrome horn, lift-up louvered hood, fold-down rumble seat, working steering system, chrome-covered spare, opening doors, detailed and wired engine. Color black.',
#   'quantityInStock': 548,
#   'buyPrice': 72.56,
#   'MSRP': 168.75},
#  {'productCode': 'S18_2870',
#   'productName': '1999 Indy 500 Monte Carlo SS',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Red Start Diecast',
#   'productDescription': 'Features include opening and closing doors. Color: Red',
#   'quantityInStock': 8164,
#   'buyPrice': 56.76,
#   'MSRP': 132.0},
#  {'productCode': 'S18_2949',
#   'productName': '1913 Ford Model T Speedster',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'This 250 part reproduction includes moving handbrakes, clutch, throttle and foot pedals, squeezable horn, detailed wired engine, removable water, gas, and oil cans, pivoting monocle windshield, all topped with a baked enamel red finish. Each replica comes with an Owners Title and Certificate of Authenticity. Color red.',
#   'quantityInStock': 4189,
#   'buyPrice': 60.78,
#   'MSRP': 101.31},
#  {'productCode': 'S18_2957',
#   'productName': '1934 Ford V8 Coupe',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'Chrome Trim, Chrome Grille, Opening Hood, Opening Doors, Opening Trunk, Detailed Engine, Working Steering System',
#   'quantityInStock': 5649,
#   'buyPrice': 34.35,
#   'MSRP': 62.46},
#  {'productCode': 'S18_3029',
#   'productName': '1999 Yamaha Speed Boat',
#   'productLine': 'Ships',
#   'productScale': '4680.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'Exact replica. Wood and Metal. Many extras including rigging, long boats, pilot house, anchors, etc. Comes with three masts, all square-rigged.',
#   'quantityInStock': 4259,
#   'buyPrice': 51.61,
#   'MSRP': 86.02},
#  {'productCode': 'S18_3136',
#   'productName': '18th Century Vintage Horse Carriage',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Red Start Diecast',
#   'productDescription': 'Hand crafted diecast-like metal horse carriage is re-created in about 1:18 scale of antique horse carriage. This antique style metal Stagecoach is all hand-assembled with many different parts.\n\nThis collectible metal horse carriage is painted in classic Red, and features turning steering wheel and is entirely hand-finished.',
#   'quantityInStock': 5992,
#   'buyPrice': 60.74,
#   'MSRP': 104.72},
#  {'productCode': 'S18_3140',
#   'productName': '1903 Ford Model A',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'Features opening trunk,  working steering system',
#   'quantityInStock': 3913,
#   'buyPrice': 68.3,
#   'MSRP': 136.59},
#  {'productCode': 'S18_3232',
#   'productName': '1992 Ferrari 360 Spider red',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'his replica features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 8347,
#   'buyPrice': 77.9,
#   'MSRP': 169.34},
#  {'productCode': 'S18_3233',
#   'productName': '1985 Toyota Supra',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'This model features soft rubber tires, working steering, rubber mud guards, authentic Ford logos, detailed undercarriage, opening doors and hood, removable split rear gate, full size spare mounted in bed, detailed interior with opening glove box',
#   'quantityInStock': 7733,
#   'buyPrice': 57.01,
#   'MSRP': 107.57},
#  {'productCode': 'S18_3259',
#   'productName': 'Collectable Wooden Train',
#   'productLine': 'Trains',
#   'productScale': '4680.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'Hand crafted wooden toy train set is in about 1:18 scale, 25 inches in total length including 2 additional carts, of actual vintage train. This antique style wooden toy train model set is all hand-assembled with 100% wood.',
#   'quantityInStock': 6450,
#   'buyPrice': 67.56,
#   'MSRP': 100.84},
#  {'productCode': 'S18_3278',
#   'productName': '1969 Dodge Super Bee',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'This replica features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 1917,
#   'buyPrice': 49.05,
#   'MSRP': 80.41},
#  {'productCode': 'S18_3320',
#   'productName': '1917 Maxwell Touring Car',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'Features Gold Trim, Full Size Spare Tire, Chrome Trim, Chrome Grille, Opening Hood, Opening Doors, Opening Trunk, Detailed Engine, Working Steering System',
#   'quantityInStock': 7913,
#   'buyPrice': 57.54,
#   'MSRP': 99.21},
#  {'productCode': 'S18_3482',
#   'productName': '1976 Ford Gran Torino',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'Highly detailed 1976 Ford Gran Torino "Starsky and Hutch" diecast model. Very well constructed and painted in red and white patterns.',
#   'quantityInStock': 9127,
#   'buyPrice': 73.49,
#   'MSRP': 146.99},
#  {'productCode': 'S18_3685',
#   'productName': '1948 Porsche Type 356 Roadster',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'This model features working front and rear suspension on accurately replicated and actuating shock absorbers as well as opening engine cover, rear stabilizer flap,  and 4 opening doors.',
#   'quantityInStock': 8990,
#   'buyPrice': 62.16,
#   'MSRP': 141.28},
#  {'productCode': 'S18_3782',
#   'productName': '1957 Vespa GS150',
#   'productLine': 'Motorcycles',
#   'productScale': '4680.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'Features rotating wheels , working kick stand. Comes with stand.',
#   'quantityInStock': 7689,
#   'buyPrice': 32.95,
#   'MSRP': 62.17},
#  {'productCode': 'S18_3856',
#   'productName': '1941 Chevrolet Special Deluxe Cabriolet',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'Features opening hood, opening doors, opening trunk, wide white wall tires, front door arm rests, working steering system, leather upholstery. Color black.',
#   'quantityInStock': 2378,
#   'buyPrice': 64.58,
#   'MSRP': 105.87},
#  {'productCode': 'S18_4027',
#   'productName': '1970 Triumph Spitfire',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'Features include opening and closing doors. Color: White.',
#   'quantityInStock': 5545,
#   'buyPrice': 91.92,
#   'MSRP': 143.62},
#  {'productCode': 'S18_4409',
#   'productName': '1932 Alfa Romeo 8C2300 Spider Sport',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'This 1:18 scale precision die cast replica features the 6 front headlights of the original, plus a detailed version of the 142 horsepower straight 8 engine, dual spares and their famous comprehensive dashboard. Color black.',
#   'quantityInStock': 6553,
#   'buyPrice': 43.26,
#   'MSRP': 92.03},
#  {'productCode': 'S18_4522',
#   'productName': '1904 Buick Runabout',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'Features opening trunk,  working steering system',
#   'quantityInStock': 8290,
#   'buyPrice': 52.66,
#   'MSRP': 87.77},
#  {'productCode': 'S18_4600',
#   'productName': '1940s Ford truck',
#   'productLine': 'Trucks and Buses',
#   'productScale': '4680.0',
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': "This 1940s Ford Pick-Up truck is re-created in 1:18 scale of original 1940s Ford truck. This antique style metal 1940s Ford Flatbed truck is all hand-assembled. This collectible 1940's Pick-Up truck is painted in classic dark green color, and features rotating wheels.",
#   'quantityInStock': 3128,
#   'buyPrice': 84.76,
#   'MSRP': 121.08},
#  {'productCode': 'S18_4668',
#   'productName': '1939 Cadillac Limousine',
#   'productLine': 'Vintage Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'Features completely detailed interior including Velvet flocked drapes,deluxe wood grain floor, and a wood grain casket with seperate chrome handles',
#   'quantityInStock': 6645,
#   'buyPrice': 23.14,
#   'MSRP': 50.31},
#  {'productCode': 'S18_4721',
#   'productName': '1957 Corvette Convertible',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': '1957 die cast Corvette Convertible in Roman Red with white sides and whitewall tires. 1:18 scale quality die-cast with detailed engine and underbvody. Now you can own The Classic Corvette.',
#   'quantityInStock': 1249,
#   'buyPrice': 69.93,
#   'MSRP': 148.8},
#  {'productCode': 'S18_4933',
#   'productName': '1957 Ford Thunderbird',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'This 1:18 scale precision die-cast replica, with its optional porthole hardtop and factory baked-enamel Thunderbird Bronze finish, is a 100% accurate rendition of this American classic.',
#   'quantityInStock': 3209,
#   'buyPrice': 34.21,
#   'MSRP': 71.27},
#  {'productCode': 'S24_1046',
#   'productName': '1970 Chevy Chevelle SS 454',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'This model features rotating wheels, working streering system and opening doors. All parts are particularly delicate due to their precise scale and require special care and attention. It should not be picked up by the doors, roof, hood or trunk.',
#   'quantityInStock': 1005,
#   'buyPrice': 49.24,
#   'MSRP': 73.49},
#  {'productCode': 'S24_1444',
#   'productName': '1970 Dodge Coronet',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': '1:24 scale die-cast about 18" long doors open, hood opens and rubber wheels',
#   'quantityInStock': 4074,
#   'buyPrice': 32.37,
#   'MSRP': 57.8},
#  {'productCode': 'S24_1578',
#   'productName': '1997 BMW R 1100 S',
#   'productLine': 'Motorcycles',
#   'productScale': '5040.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'Detailed scale replica with working suspension and constructed from over 70 parts',
#   'quantityInStock': 7003,
#   'buyPrice': 60.86,
#   'MSRP': 112.7},
#  {'productCode': 'S24_1628',
#   'productName': '1966 Shelby Cobra 427 S/C',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': "This diecast model of the 1966 Shelby Cobra 427 S/C includes many authentic details and operating parts. The 1:24 scale model of this iconic lighweight sports car from the 1960s comes in silver and it's own display case.",
#   'quantityInStock': 8197,
#   'buyPrice': 29.18,
#   'MSRP': 50.31},
#  {'productCode': 'S24_1785',
#   'productName': '1928 British Royal Navy Airplane',
#   'productLine': 'Planes',
#   'productScale': '5040.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'Official logos and insignias',
#   'quantityInStock': 3627,
#   'buyPrice': 66.74,
#   'MSRP': 109.42},
#  {'productCode': 'S24_1937',
#   'productName': '1939 Chevrolet Deluxe Coupe',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': 'This 1:24 scale die-cast replica of the 1939 Chevrolet Deluxe Coupe has the same classy look as the original. Features opening trunk, hood and doors and a showroom quality baked enamel finish.',
#   'quantityInStock': 7332,
#   'buyPrice': 22.57,
#   'MSRP': 33.19},
#  {'productCode': 'S24_2000',
#   'productName': '1960 BSA Gold Star DBD34 1960',
#   'productLine': 'Motorcycles',
#   'productScale': '5040.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'Detailed scale replica with working suspension and constructed from over 70 parts',
#   'quantityInStock': 15,
#   'buyPrice': 37.32,
#   'MSRP': 76.17},
#  {'productCode': 'S24_2011',
#   'productName': '18th century schooner',
#   'productLine': 'Ships',
#   'productScale': '5040.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'All wood with canvas sails. Many extras including rigging, long boats, pilot house, anchors, etc. Comes with 4 masts, all square-rigged.',
#   'quantityInStock': 1898,
#   'buyPrice': 82.34,
#   'MSRP': 122.89},
#  {'productCode': 'S24_2022',
#   'productName': '1938 Cadillac V-16 Presidential Limousine',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'This 1:24 scale precision die cast replica of the 1938 Cadillac V-16 Presidential Limousine has all the details of the original, from the flags on the front to an opening back seat compartment complete with telephone and rifle. Features factory baked-enamel black finish, hood goddess ornament, working jump seats.',
#   'quantityInStock': 2847,
#   'buyPrice': 20.61,
#   'MSRP': 44.8},
#  {'productCode': 'S24_2300',
#   'productName': '1962 Volkswagen Microbus',
#   'productLine': 'Trucks and Buses',
#   'productScale': '5040.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'This 1:18 scale die cast replica of the 1962 Microbus is loaded with features: A working steering system, opening front doors and tailgate, and famous two-tone factory baked enamel finish, are all topped of by the sliding, real fabric, sunroof.',
#   'quantityInStock': 2327,
#   'buyPrice': 61.34,
#   'MSRP': 127.79},
#  {'productCode': 'S24_2360',
#   'productName': '1982 Ducati 900 Monster',
#   'productLine': 'Motorcycles',
#   'productScale': '5040.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'Features two-tone paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand',
#   'quantityInStock': 6840,
#   'buyPrice': 47.1,
#   'MSRP': 69.26},
#  {'productCode': 'S24_2766',
#   'productName': '1949 Jaguar XK 120',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'Precision-engineered from original Jaguar specification in perfect scale ratio. Features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 2350,
#   'buyPrice': 47.25,
#   'MSRP': 90.87},
#  {'productCode': 'S24_2840',
#   'productName': '1958 Chevy Corvette Limited Edition',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'The operating parts of this 1958 Chevy Corvette Limited Edition are particularly delicate due to their precise scale and require special care and attention. Features rotating wheels, working streering, opening doors and trunk. Color dark green.',
#   'quantityInStock': 2542,
#   'buyPrice': 15.91,
#   'MSRP': 35.36},
#  {'productCode': 'S24_2841',
#   'productName': '1900s Vintage Bi-Plane',
#   'productLine': 'Planes',
#   'productScale': '5040.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'Hand crafted diecast-like metal bi-plane is re-created in about 1:24 scale of antique pioneer airplane. All hand-assembled with many different parts. Hand-painted in classic yellow and features correct markings of original airplane.',
#   'quantityInStock': 5942,
#   'buyPrice': 34.25,
#   'MSRP': 68.51},
#  {'productCode': 'S24_2887',
#   'productName': '1952 Citroen-15CV',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'Precision crafted hand-assembled 1:18 scale reproduction of the 1952 15CV, with its independent spring suspension, working steering system, opening doors and hood, detailed engine and instrument panel, all topped of with a factory fresh baked enamel finish.',
#   'quantityInStock': 1452,
#   'buyPrice': 72.82,
#   'MSRP': 117.44},
#  {'productCode': 'S24_2972',
#   'productName': '1982 Lamborghini Diablo',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'This replica features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 7723,
#   'buyPrice': 16.24,
#   'MSRP': 37.76},
#  {'productCode': 'S24_3151',
#   'productName': '1912 Ford Model T Delivery Wagon',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'This model features chrome trim and grille, opening hood, opening doors, opening trunk, detailed engine, working steering system. Color white.',
#   'quantityInStock': 9173,
#   'buyPrice': 46.91,
#   'MSRP': 88.51},
#  {'productCode': 'S24_3191',
#   'productName': '1969 Chevrolet Camaro Z28',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': '1969 Z/28 Chevy Camaro 1:24 scale replica. The operating parts of this limited edition 1:24 scale diecast model car 1969 Chevy Camaro Z28- hood, trunk, wheels, streering, suspension and doors- are particularly delicate due to their precise scale and require special care and attention.',
#   'quantityInStock': 4695,
#   'buyPrice': 50.51,
#   'MSRP': 85.61},
#  {'productCode': 'S24_3371',
#   'productName': '1971 Alpine Renault 1600s',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': 'This 1971 Alpine Renault 1600s replica Features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 7995,
#   'buyPrice': 38.58,
#   'MSRP': 61.23},
#  {'productCode': 'S24_3420',
#   'productName': '1937 Horch 930V Limousine',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'Features opening hood, opening doors, opening trunk, wide white wall tires, front door arm rests, working steering system',
#   'quantityInStock': 2902,
#   'buyPrice': 26.3,
#   'MSRP': 65.75},
#  {'productCode': 'S24_3432',
#   'productName': '2002 Chevy Corvette',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'The operating parts of this limited edition Diecast 2002 Chevy Corvette 50th Anniversary Pace car Limited Edition are particularly delicate due to their precise scale and require special care and attention. Features rotating wheels, poseable streering, opening doors and trunk.',
#   'quantityInStock': 9446,
#   'buyPrice': 62.11,
#   'MSRP': 107.08},
#  {'productCode': 'S24_3816',
#   'productName': '1940 Ford Delivery Sedan',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'Chrome Trim, Chrome Grille, Opening Hood, Opening Doors, Opening Trunk, Detailed Engine, Working Steering System. Color black.',
#   'quantityInStock': 6621,
#   'buyPrice': 48.64,
#   'MSRP': 83.86},
#  {'productCode': 'S24_3856',
#   'productName': '1956 Porsche 356A Coupe',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.',
#   'quantityInStock': 6600,
#   'buyPrice': 98.3,
#   'MSRP': 140.43},
#  {'productCode': 'S24_3949',
#   'productName': 'Corsair F4U ( Bird Cage)',
#   'productLine': 'Planes',
#   'productScale': '5040.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'Has retractable wheels and comes with a stand. Official logos and insignias.',
#   'quantityInStock': 6812,
#   'buyPrice': 29.34,
#   'MSRP': 68.24},
#  {'productCode': 'S24_3969',
#   'productName': '1936 Mercedes Benz 500k Roadster',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Red Start Diecast',
#   'productDescription': 'This model features grille-mounted chrome horn, lift-up louvered hood, fold-down rumble seat, working steering system and rubber wheels. Color black.',
#   'quantityInStock': 2081,
#   'buyPrice': 21.75,
#   'MSRP': 41.03},
#  {'productCode': 'S24_4048',
#   'productName': '1992 Porsche Cayenne Turbo Silver',
#   'productLine': 'Classic Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'This replica features opening doors, superb detail and craftsmanship, working steering system, opening forward compartment, opening rear trunk with removable spare, 4 wheel independent spring suspension as well as factory baked enamel finish.',
#   'quantityInStock': 6582,
#   'buyPrice': 69.78,
#   'MSRP': 118.28},
#  {'productCode': 'S24_4258',
#   'productName': '1936 Chrysler Airflow',
#   'productLine': 'Vintage Cars',
#   'productScale': '5040.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'Features opening trunk,  working steering system. Color dark green.',
#   'quantityInStock': 4710,
#   'buyPrice': 57.46,
#   'MSRP': 97.39},
#  {'productCode': 'S24_4278',
#   'productName': '1900s Vintage Tri-Plane',
#   'productLine': 'Planes',
#   'productScale': '5040.0',
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'Hand crafted diecast-like metal Triplane is Re-created in about 1:24 scale of antique pioneer airplane. This antique style metal triplane is all hand-assembled with many different parts.',
#   'quantityInStock': 2756,
#   'buyPrice': 36.23,
#   'MSRP': 72.45},
#  {'productCode': 'S24_4620',
#   'productName': '1961 Chevrolet Impala',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'This 1:18 scale precision die-cast reproduction of the 1961 Chevrolet Impala has all the features-doors, hood and trunk that open; detailed 409 cubic-inch engine; chrome dashboard and stick shift, two-tone interior; working steering system; all topped of with a factory baked-enamel finish.',
#   'quantityInStock': 7869,
#   'buyPrice': 32.33,
#   'MSRP': 80.84},
#  {'productCode': 'S32_1268',
#   'productName': '1980\x92s GM Manhattan Express',
#   'productLine': 'Trucks and Buses',
#   'productScale': '5520.0',
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': 'This 1980\x92s era new look Manhattan express is still active, running from the Bronx to mid-town Manhattan. Has 35 opeining windows and working lights. Needs a battery.',
#   'quantityInStock': 5099,
#   'buyPrice': 53.93,
#   'MSRP': 96.31},
#  {'productCode': 'S32_1374',
#   'productName': '1997 BMW F650 ST',
#   'productLine': 'Motorcycles',
#   'productScale': '5520.0',
#   'productVendor': 'Exoto Designs',
#   'productDescription': 'Features official die-struck logos and baked enamel finish. Comes with stand.',
#   'quantityInStock': 178,
#   'buyPrice': 66.92,
#   'MSRP': 99.89},
#  {'productCode': 'S32_2206',
#   'productName': '1982 Ducati 996 R',
#   'productLine': 'Motorcycles',
#   'productScale': '5520.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'Features rotating wheels , working kick stand. Comes with stand.',
#   'quantityInStock': 9241,
#   'buyPrice': 24.14,
#   'MSRP': 40.23},
#  {'productCode': 'S32_2509',
#   'productName': '1954 Greyhound Scenicruiser',
#   'productLine': 'Trucks and Buses',
#   'productScale': '5520.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'Model features bi-level seating, 50 windows, skylights & glare resistant glass, working steering system, original logos',
#   'quantityInStock': 2874,
#   'buyPrice': 25.98,
#   'MSRP': 54.11},
#  {'productCode': 'S32_3207',
#   'productName': "1950's Chicago Surface Lines Streetcar",
#   'productLine': 'Trains',
#   'productScale': '5520.0',
#   'productVendor': 'Gearbox Collectibles',
#   'productDescription': 'This streetcar is a joy to see. It has 80 separate windows, electric wire guides, detailed interiors with seats, poles and drivers controls, rolling and turning wheel assemblies, plus authentic factory baked-enamel finishes (Green Hornet for Chicago and Cream and Crimson for Boston).',
#   'quantityInStock': 8601,
#   'buyPrice': 26.72,
#   'MSRP': 62.14},
#  {'productCode': 'S32_3522',
#   'productName': '1996 Peterbilt 379 Stake Bed with Outrigger',
#   'productLine': 'Trucks and Buses',
#   'productScale': '5520.0',
#   'productVendor': 'Red Start Diecast',
#   'productDescription': 'This model features, opening doors, detailed engine, working steering, tinted windows, detailed interior, die-struck logos, removable stakes operating outriggers, detachable second trailer, functioning 360-degree self loader, precision molded resin trailer and trim, baked enamel finish on cab',
#   'quantityInStock': 814,
#   'buyPrice': 33.61,
#   'MSRP': 64.64},
#  {'productCode': 'S32_4289',
#   'productName': '1928 Ford Phaeton Deluxe',
#   'productLine': 'Vintage Cars',
#   'productScale': '5520.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'This model features grille-mounted chrome horn, lift-up louvered hood, fold-down rumble seat, working steering system',
#   'quantityInStock': 136,
#   'buyPrice': 33.02,
#   'MSRP': 68.79},
#  {'productCode': 'S32_4485',
#   'productName': '1974 Ducati 350 Mk3 Desmo',
#   'productLine': 'Motorcycles',
#   'productScale': '5520.0',
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'This model features two-tone paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand',
#   'quantityInStock': 3341,
#   'buyPrice': 56.13,
#   'MSRP': 102.05},
#  {'productCode': 'S50_1341',
#   'productName': '1930 Buick Marquette Phaeton',
#   'productLine': 'Vintage Cars',
#   'productScale': '6600.0',
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'Features opening trunk,  working steering system',
#   'quantityInStock': 7062,
#   'buyPrice': 27.06,
#   'MSRP': 43.64},
#  {'productCode': 'S50_1392',
#   'productName': 'Diamond T620 Semi-Skirted Tanker',
#   'productLine': 'Trucks and Buses',
#   'productScale': '6600.0',
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'This limited edition model is licensed and perfectly scaled for Lionel Trains. The Diamond T620 has been produced in solid precision diecast and painted with a fire baked enamel finish. It comes with a removable tanker and is a perfect model to add authenticity to your static train or car layout or to just have on display.',
#   'quantityInStock': 1016,
#   'buyPrice': 68.29,
#   'MSRP': 115.75},
#  {'productCode': 'S50_1514',
#   'productName': '1962 City of Detroit Streetcar',
#   'productLine': 'Trains',
#   'productScale': '6600.0',
#   'productVendor': 'Classic Metal Creations',
#   'productDescription': 'This streetcar is a joy to see. It has 99 separate windows, electric wire guides, detailed interiors with seats, poles and drivers controls, rolling and turning wheel assemblies, plus authentic factory baked-enamel finishes (Green Hornet for Chicago and Cream and Crimson for Boston).',
#   'quantityInStock': 1645,
#   'buyPrice': 37.49,
#   'MSRP': 58.58},
#  {'productCode': 'S50_4713',
#   'productName': '2002 Yamaha YZR M1',
#   'productLine': 'Motorcycles',
#   'productScale': '6600.0',
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'Features rotating wheels , working kick stand. Comes with stand.',
#   'quantityInStock': 600,
#   'buyPrice': 34.17,
#   'MSRP': 81.36},
#  {'productCode': 'S700_1138',
#   'productName': 'The Schooner Bluenose',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Autoart Studio Design',
#   'productDescription': 'All wood with canvas sails. Measures 31 1/2 inches in Length, 22 inches High and 4 3/4 inches Wide. Many extras.\nThe schooner Bluenose was built in Nova Scotia in 1921 to fish the rough waters off the coast of Newfoundland. Because of the Bluenose racing prowess she became the pride of all Canadians. Still featured on stamps and the Canadian dime, the Bluenose was lost off Haiti in 1946.',
#   'quantityInStock': 1897,
#   'buyPrice': 34.0,
#   'MSRP': 66.67},
#  {'productCode': 'S700_1691',
#   'productName': 'American Airlines: B767-300',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Min Lin Diecast',
#   'productDescription': 'Exact replia with official logos and insignias and retractable wheels',
#   'quantityInStock': 5841,
#   'buyPrice': 51.15,
#   'MSRP': 91.34},
#  {'productCode': 'S700_1938',
#   'productName': 'The Mayflower',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Studio M Art Models',
#   'productDescription': 'Measures 31 1/2 inches Long x 25 1/2 inches High x 10 5/8 inches Wide\nAll wood with canvas sail. Extras include long boats, rigging, ladders, railing, anchors, side cannons, hand painted, etc.\n\nThe Mayfower was already old in 1620, when the pilgrims charted her to bring their band of 103 to North America.',
#   'quantityInStock': 737,
#   'buyPrice': 43.3,
#   'MSRP': 86.61},
#  {'productCode': 'S700_2047',
#   'productName': 'HMS Bounty',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'Measures 30 inches Long x 27 1/2 inches High x 4 3/4 inches Wide. \nMany extras including rigging, long boats, pilot house, anchors, etc. Comes with three masts, all square-rigged.',
#   'quantityInStock': 3501,
#   'buyPrice': 39.83,
#   'MSRP': 90.52},
#  {'productCode': 'S700_2466',
#   'productName': 'America West Airlines B757-200',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': 'Official logos and insignias. Working steering system. Rotating jet engines',
#   'quantityInStock': 9653,
#   'buyPrice': 68.8,
#   'MSRP': 99.72},
#  {'productCode': 'S700_2610',
#   'productName': 'The USS Constitution Ship',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Red Start Diecast',
#   'productDescription': 'All wood with canvas sails. Measures 31 1/2" Length x 22 3/8" High x 8 1/4" Width. Extras include 4 boats on deck, sea sprite on bow, anchors, copper railing, pilot houses, etc.\n\nThis was one of six warships commissioned by George Washington and launched in 1797. The nickname Old Ironsides was given the ship when British cannonballs bounced off the 21-inch oak planking of the American frigate\'s hull. The Constitution has been restored and now resides in Boston Harbor.',
#   'quantityInStock': 7083,
#   'buyPrice': 33.97,
#   'MSRP': 72.28},
#  {'productCode': 'S700_2824',
#   'productName': '1982 Camaro Z28',
#   'productLine': 'Classic Cars',
#   'productScale': '4680.0',
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'Features include opening and closing doors. Color: White. \nMeasures approximately 9 1/2" Long.',
#   'quantityInStock': 6934,
#   'buyPrice': 46.53,
#   'MSRP': 101.15},
#  {'productCode': 'S700_2834',
#   'productName': 'ATA: B757-300',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Highway 66 Mini Classics',
#   'productDescription': 'Exact replia with official logos and insignias and retractable wheels',
#   'quantityInStock': 7106,
#   'buyPrice': 59.33,
#   'MSRP': 118.65},
#  {'productCode': 'S700_3167',
#   'productName': 'F/A 18 Hornet 1/72',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': '10" Wingspan with retractable landing gears.Comes with pilot',
#   'quantityInStock': 551,
#   'buyPrice': 54.4,
#   'MSRP': 80.0},
#  {'productCode': 'S700_3505',
#   'productName': 'The Titanic',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Carousel DieCast Legends',
#   'productDescription': 'Completed model measures 19 1/2 inches long, 9 inches high, 3inches wide and is in barn red/black. All wood and metal.',
#   'quantityInStock': 1956,
#   'buyPrice': 51.09,
#   'MSRP': 100.17},
#  {'productCode': 'S700_3962',
#   'productName': 'The Queen Mary',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Welly Diecast Productions',
#   'productDescription': 'Exact replica. Wood and Metal. Many extras including rigging, long boats, pilot house, anchors, etc. Comes with three masts, all square-rigged.',
#   'quantityInStock': 5088,
#   'buyPrice': 53.63,
#   'MSRP': 99.31},
#  {'productCode': 'S700_4002',
#   'productName': 'American Airlines: MD-11S',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Second Gear Diecast',
#   'productDescription': 'Polished finish. Exact replia with official logos and insignias and retractable wheels',
#   'quantityInStock': 8820,
#   'buyPrice': 36.27,
#   'MSRP': 74.03},
#  {'productCode': 'S72_1253',
#   'productName': 'Boeing X-32A JSF',
#   'productLine': 'Planes',
#   'productScale': None,
#   'productVendor': 'Motor City Art Classics',
#   'productDescription': '10" Wingspan with retractable landing gears.Comes with pilot',
#   'quantityInStock': 4857,
#   'buyPrice': 32.77,
#   'MSRP': 49.66},
#  {'productCode': 'S72_3212',
#   'productName': 'Pont Yacht',
#   'productLine': 'Ships',
#   'productScale': None,
#   'productVendor': 'Unimax Art Galleries',
#   'productDescription': 'Measures 38 inches Long x 33 3/4 inches High. Includes a stand.\nMany extras including rigging, long boats, pilot house, anchors, etc. Comes with 2 masts, all square-rigged',
#   'quantityInStock': 414,
#   'buyPrice': 33.3,
#   'MSRP': 54.6}]

# %% [markdown]
# # Imbriquer nos extractions de table pour créer la collection Offices

# %%
offices = offices.assign(
Employees = [list(employees.query("officeCode == @id").drop(columns=["officeCode"]).to_dict(orient="records")) if id in list(employees.officeCode) else None for id in offices.officeCode])

# %% [markdown]
# # Visualisation de la collection Offices

# %%
offices.to_dict(orient = "records") #Extraction en documents de offices
# Out:
# [{'officeCode': '1.0',
#   'city': 'San Francisco',
#   'phone': '+1 650 219 4782',
#   'addressLine1': '100 Market Street',
#   'addressLine2': 'Suite 300',
#   'state': 'CA',
#   'country': 'USA',
#   'postalCode': '94080',
#   'territory': None,
#   'Employees': [{'employeeNumber': 1002,
#     'lastName': 'Murphy',
#     'firstName': 'Diane',
#     'extension': 'x5800',
#     'email': 'dmurphy@classicmodelcars.com',
#     'reportsTo': 'NULL',
#     'jobTitle': 'President'},
#    {'employeeNumber': 1056,
#     'lastName': 'Patterson',
#     'firstName': 'Mary',
#     'extension': 'x4611',
#     'email': 'mpatterso@classicmodelcars.com',
#     'reportsTo': 1002,
#     'jobTitle': 'VP Sales'},
#    {'employeeNumber': 1076,
#     'lastName': 'Firrelli',
#     'firstName': 'Jeff',
#     'extension': 'x9273',
#     'email': 'jfirrelli@classicmodelcars.com',
#     'reportsTo': 1002,
#     'jobTitle': 'VP Marketing'},
#    {'employeeNumber': 1143,
#     'lastName': 'Bow',
#     'firstName': 'Anthony',
#     'extension': 'x5428',
#     'email': 'bhoward@classicmodelcars.com',
#     'reportsTo': 1056,
#     'jobTitle': 'Sales Manager (NA)'},
#    {'employeeNumber': 1165,
#     'lastName': 'Jennings',
#     'firstName': 'Leslie',
#     'extension': 'x3291',
#     'email': 'ljennings@classicmodelcars.com',
#     'reportsTo': 1143,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1166,
#     'lastName': 'Thompson',
#     'firstName': 'Leslie',
#     'extension': 'x4065',
#     'email': 'lthompson@classicmodelcars.com',
#     'reportsTo': 1143,
#     'jobTitle': 'Sales Rep'}]},
#  {'officeCode': '2.0',
#   'city': 'Boston',
#   'phone': '+1 215 837 0825',
#   'addressLine1': '1550 Court Place',
#   'addressLine2': 'Suite 102',
#   'state': 'MA',
#   'country': 'USA',
#   'postalCode': '02107',
#   'territory': None,
#   'Employees': [{'employeeNumber': 1188,
#     'lastName': 'Firrelli',
#     'firstName': 'Julie',
#     'extension': 'x2173',
#     'email': 'jfirrelli@classicmodelcars.com',
#     'reportsTo': 1143,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1216,
#     'lastName': 'Patterson',
#     'firstName': 'Steve',
#     'extension': 'x4334',
#     'email': 'spatterso@classicmodelcars.com',
#     'reportsTo': 1143,
#     'jobTitle': 'Sales Rep'}]},
#  {'officeCode': '3.0',
#   'city': 'NYC',
#   'phone': '+1 212 555 3000',
#   'addressLine1': '523 East 53rd Street',
#   'addressLine2': 'apt. 5A',
#   'state': 'NY',
#   'country': 'USA',
#   'postalCode': '10022',
#   'territory': None,
#   'Employees': [{'employeeNumber': 1286,
#     'lastName': 'Tseng',
#     'firstName': 'Foon Yue',
#     'extension': 'x2248',
#     'email': 'ftseng@classicmodelcars.com',
#     'reportsTo': 1143,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1323,
#     'lastName': 'Vanauf',
#     'firstName': 'George',
#     'extension': 'x4102',
#     'email': 'gvanauf@classicmodelcars.com',
#     'reportsTo': 1143,
#     'jobTitle': 'Sales Rep'}]},
#  {'officeCode': '4.0',
#   'city': 'Paris',
#   'phone': '+33 14 723 4404',
#   'addressLine1': "43 Rue Jouffroy D'abbans",
#   'addressLine2': 'NULL',
#   'state': None,
#   'country': 'France',
#   'postalCode': '75017',
#   'territory': 'EMEA',
#   'Employees': [{'employeeNumber': 1102,
#     'lastName': 'Bondur',
#     'firstName': 'Gerard',
#     'extension': 'x5408',
#     'email': 'athompson@classicmodelcars.com',
#     'reportsTo': 1056,
#     'jobTitle': 'Sale Manager (EMEA)'},
#    {'employeeNumber': 1337,
#     'lastName': 'Bondur',
#     'firstName': 'Loui',
#     'extension': 'x6493',
#     'email': 'lbondur@classicmodelcars.com',
#     'reportsTo': 1102,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1370,
#     'lastName': 'Hernandez',
#     'firstName': 'Gerard',
#     'extension': 'x2028',
#     'email': 'ghernande@classicmodelcars.com',
#     'reportsTo': 1102,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1401,
#     'lastName': 'Castillo',
#     'firstName': 'Pamela',
#     'extension': 'x2759',
#     'email': 'pcastillo@classicmodelcars.com',
#     'reportsTo': 1102,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1702,
#     'lastName': 'Gerard',
#     'firstName': 'Martin',
#     'extension': 'x2312',
#     'email': 'gmartin@classicmodelcars.com',
#     'reportsTo': 1102,
#     'jobTitle': 'Sales Rep'}]},
#  {'officeCode': '5.0',
#   'city': 'Tokyo',
#   'phone': '+81 33 224 5000',
#   'addressLine1': '4-1 Kioicho',
#   'addressLine2': 'NULL',
#   'state': 'Chiyoda-Ku',
#   'country': 'Japan',
#   'postalCode': '102-8578',
#   'territory': 'Japan',
#   'Employees': [{'employeeNumber': 1621,
#     'lastName': 'Nishi',
#     'firstName': 'Mami',
#     'extension': 'x101',
#     'email': 'mnishi@classicmodelcars.com',
#     'reportsTo': 1088,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1625,
#     'lastName': 'Kato',
#     'firstName': 'Yoshimi',
#     'extension': 'x102',
#     'email': 'ekato@classicmodelcars.com',
#     'reportsTo': 1088,
#     'jobTitle': 'Sales Rep'}]},
#  {'officeCode': '6.0',
#   'city': 'Sydney',
#   'phone': '+61 2 9264 2451',
#   'addressLine1': '5-11 Wentworth Avenue',
#   'addressLine2': 'Floor #2',
#   'state': 'NULL',
#   'country': 'Australia',
#   'postalCode': 'NSW 2010',
#   'territory': 'APAC',
#   'Employees': [{'employeeNumber': 1088,
#     'lastName': 'Patterson',
#     'firstName': 'William',
#     'extension': 'x4871',
#     'email': 'wpatterson@classicmodelcars.com',
#     'reportsTo': 1056,
#     'jobTitle': 'Sales Manager (JAPAN, APAC)'},
#    {'employeeNumber': 1611,
#     'lastName': 'Fixter',
#     'firstName': 'Andy',
#     'extension': 'x101',
#     'email': 'afixter@classicmodelcars.com',
#     'reportsTo': 1088,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1612,
#     'lastName': 'Marsh',
#     'firstName': 'Peter',
#     'extension': 'x102',
#     'email': 'pmarsh@classicmodelcars.com',
#     'reportsTo': 1088,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1619,
#     'lastName': 'King',
#     'firstName': 'Tom',
#     'extension': 'x103',
#     'email': 'tking@classicmodelcars.com',
#     'reportsTo': 1088,
#     'jobTitle': 'Sales Rep'}]},
#  {'officeCode': '7.0',
#   'city': 'London',
#   'phone': '+44 20 7877 2041',
#   'addressLine1': '25 Old Broad Street',
#   'addressLine2': 'Level 7',
#   'state': 'NULL',
#   'country': 'UK',
#   'postalCode': 'EC2N 1HN',
#   'territory': 'EMEA',
#   'Employees': [{'employeeNumber': 1501,
#     'lastName': 'Bott',
#     'firstName': 'Larry',
#     'extension': 'x2311',
#     'email': 'lbott@classicmodelcars.com',
#     'reportsTo': 1102,
#     'jobTitle': 'Sales Rep'},
#    {'employeeNumber': 1504,
#     'lastName': 'Jones',
#     'firstName': 'Barry',
#     'extension': 'x102',
#     'email': 'bjones@classicmodelcars.com',
#     'reportsTo': 1102,
#     'jobTitle': 'Sales Rep'}]}]

# %% [markdown]
# # Import des données dans dans le serveur MongoDB

# %%
db.Customers.insert_many(
    customers.to_dict(orient = "records") #Extraction en documents de customers
)

db.Offices.insert_many(
    offices.to_dict(orient = "records") #Extraction en documents de customers
)

db.Products.insert_many(
    products.to_dict(orient = "records") #Extraction en documents de customers
)
# Out:
# InsertManyResult([ObjectId('674344ff13b4168c0dbb4979'), ObjectId('674344ff13b4168c0dbb497a'), ObjectId('674344ff13b4168c0dbb497b'), ObjectId('674344ff13b4168c0dbb497c'), ObjectId('674344ff13b4168c0dbb497d'), ObjectId('674344ff13b4168c0dbb497e'), ObjectId('674344ff13b4168c0dbb497f'), ObjectId('674344ff13b4168c0dbb4980'), ObjectId('674344ff13b4168c0dbb4981'), ObjectId('674344ff13b4168c0dbb4982'), ObjectId('674344ff13b4168c0dbb4983'), ObjectId('674344ff13b4168c0dbb4984'), ObjectId('674344ff13b4168c0dbb4985'), ObjectId('674344ff13b4168c0dbb4986'), ObjectId('674344ff13b4168c0dbb4987'), ObjectId('674344ff13b4168c0dbb4988'), ObjectId('674344ff13b4168c0dbb4989'), ObjectId('674344ff13b4168c0dbb498a'), ObjectId('674344ff13b4168c0dbb498b'), ObjectId('674344ff13b4168c0dbb498c'), ObjectId('674344ff13b4168c0dbb498d'), ObjectId('674344ff13b4168c0dbb498e'), ObjectId('674344ff13b4168c0dbb498f'), ObjectId('674344ff13b4168c0dbb4990'), ObjectId('674344ff13b4168c0dbb4991'), ObjectId('674344ff13b4168c0dbb4992'), ObjectId('674344ff13b4168c0dbb4993'), ObjectId('674344ff13b4168c0dbb4994'), ObjectId('674344ff13b4168c0dbb4995'), ObjectId('674344ff13b4168c0dbb4996'), ObjectId('674344ff13b4168c0dbb4997'), ObjectId('674344ff13b4168c0dbb4998'), ObjectId('674344ff13b4168c0dbb4999'), ObjectId('674344ff13b4168c0dbb499a'), ObjectId('674344ff13b4168c0dbb499b'), ObjectId('674344ff13b4168c0dbb499c'), ObjectId('674344ff13b4168c0dbb499d'), ObjectId('674344ff13b4168c0dbb499e'), ObjectId('674344ff13b4168c0dbb499f'), ObjectId('674344ff13b4168c0dbb49a0'), ObjectId('674344ff13b4168c0dbb49a1'), ObjectId('674344ff13b4168c0dbb49a2'), ObjectId('674344ff13b4168c0dbb49a3'), ObjectId('674344ff13b4168c0dbb49a4'), ObjectId('674344ff13b4168c0dbb49a5'), ObjectId('674344ff13b4168c0dbb49a6'), ObjectId('674344ff13b4168c0dbb49a7'), ObjectId('674344ff13b4168c0dbb49a8'), ObjectId('674344ff13b4168c0dbb49a9'), ObjectId('674344ff13b4168c0dbb49aa'), ObjectId('674344ff13b4168c0dbb49ab'), ObjectId('674344ff13b4168c0dbb49ac'), ObjectId('674344ff13b4168c0dbb49ad'), ObjectId('674344ff13b4168c0dbb49ae'), ObjectId('674344ff13b4168c0dbb49af'), ObjectId('674344ff13b4168c0dbb49b0'), ObjectId('674344ff13b4168c0dbb49b1'), ObjectId('674344ff13b4168c0dbb49b2'), ObjectId('674344ff13b4168c0dbb49b3'), ObjectId('674344ff13b4168c0dbb49b4'), ObjectId('674344ff13b4168c0dbb49b5'), ObjectId('674344ff13b4168c0dbb49b6'), ObjectId('674344ff13b4168c0dbb49b7'), ObjectId('674344ff13b4168c0dbb49b8'), ObjectId('674344ff13b4168c0dbb49b9'), ObjectId('674344ff13b4168c0dbb49ba'), ObjectId('674344ff13b4168c0dbb49bb'), ObjectId('674344ff13b4168c0dbb49bc'), ObjectId('674344ff13b4168c0dbb49bd'), ObjectId('674344ff13b4168c0dbb49be'), ObjectId('674344ff13b4168c0dbb49bf'), ObjectId('674344ff13b4168c0dbb49c0'), ObjectId('674344ff13b4168c0dbb49c1'), ObjectId('674344ff13b4168c0dbb49c2'), ObjectId('674344ff13b4168c0dbb49c3'), ObjectId('674344ff13b4168c0dbb49c4'), ObjectId('674344ff13b4168c0dbb49c5'), ObjectId('674344ff13b4168c0dbb49c6'), ObjectId('674344ff13b4168c0dbb49c7'), ObjectId('674344ff13b4168c0dbb49c8'), ObjectId('674344ff13b4168c0dbb49c9'), ObjectId('674344ff13b4168c0dbb49ca'), ObjectId('674344ff13b4168c0dbb49cb'), ObjectId('674344ff13b4168c0dbb49cc'), ObjectId('674344ff13b4168c0dbb49cd'), ObjectId('674344ff13b4168c0dbb49ce'), ObjectId('674344ff13b4168c0dbb49cf'), ObjectId('674344ff13b4168c0dbb49d0'), ObjectId('674344ff13b4168c0dbb49d1'), ObjectId('674344ff13b4168c0dbb49d2'), ObjectId('674344ff13b4168c0dbb49d3'), ObjectId('674344ff13b4168c0dbb49d4'), ObjectId('674344ff13b4168c0dbb49d5'), ObjectId('674344ff13b4168c0dbb49d6'), ObjectId('674344ff13b4168c0dbb49d7'), ObjectId('674344ff13b4168c0dbb49d8'), ObjectId('674344ff13b4168c0dbb49d9'), ObjectId('674344ff13b4168c0dbb49da'), ObjectId('674344ff13b4168c0dbb49db'), ObjectId('674344ff13b4168c0dbb49dc'), ObjectId('674344ff13b4168c0dbb49dd'), ObjectId('674344ff13b4168c0dbb49de'), ObjectId('674344ff13b4168c0dbb49df'), ObjectId('674344ff13b4168c0dbb49e0'), ObjectId('674344ff13b4168c0dbb ...

# %% [markdown]
# # Vérification du nombre de clients

# %%
db.Customers.count_documents({})
# Out:
# 244

# %% [markdown]
# # Vérification du nombre de bureaux

# %%
db.Offices.count_documents({})
# Out:
# 14

# %% [markdown]
# # Vérification du nombre de produits

# %%
db.Products.count_documents({})
# Out:
# 220

# %%
rq1 = db.Customers.find(
    { "Orders": None },  # None pour trouver les champs null
    { "_id": 0, "customerName": 1,"customerNumber": 1 }
)

df = pandas.DataFrame(list(rq1))
print(df)

# On liste les clients, on trouve le nom des entreprises tel que Porto Imports Co., ANG Ressellers, etc
# Out:
#     customerNumber                    customerName
# 0              169               Porto Imports Co.
# 1              247        Messner Shopping Network
# 2              293               BG&E Collectables
# 3              168          American Souvenirs Inc
# 4              206      Asian Shopping Network, Co
# 5              237                   ANG Resellers
# 6              273               Franken Gifts, Co
# 7              303                Schuyler Imports
# 8              307                Der Hund Imports
# 9              125              Havel & Zbyszek Co
# 10             223                 Natürlich Autos
# 11             335       Cramer Spezialitäten, Ltd
# 12             409  Stuttgart Collectable Exchange
# 13             477             Mit Vergnügen & Co.
# 14             481              Raanan Stores, Inc
# 15             369          Lisboa Souveniers, Inc
# 16             443        Feuer Online Stores, Inc
# 17             459                Warburg Exchange
# 18             348           Asian Treasures, Inc.
# 19             376           Precious Collectables
# 20             356            SAR Distributors, Co
# 21             361                 Kommission Auto
# 22             465             Anton Designs, Ltd.
# 23             480       Kremlin Collectables, Co.
# 24             125              Havel & Zbyszek Co
# 25             168          American Souvenirs Inc
# 26             169               Porto Imports Co.
# 27             206      Asian Shopping Network, Co
# 28             223                 Natürlich Autos
# 29             237                   ANG Resellers
# 30             247        Messner Shopping Network
# 31             273               Franken Gifts, Co
# 32             293               BG&E Collectables
# 33             303                Schuyler Imports
# 34             307                Der Hund Imports
# 35             335       Cramer Spezialitäten, Ltd
# 36             348           Asian Treasures, Inc.
# 37             356            SAR Distributors, Co
# 38             361                 Kommission Auto
# 39             369          Lisboa Souveniers, Inc
# 40             376           Precious Collectables
# 41             409  Stuttgart Collectable Exchange
# 42             443        Feuer Online Stores, Inc
# 43             459                Warburg Exchange
# 44             465             Anton Designs, Ltd.
# 45             477             Mit Vergnügen & Co.
# 46             480       Kremlin Collectables, Co.
# 47             481              Raanan Stores, Inc

# %%
rq2 = db.Offices.aggregate([
    { "$unwind": "$Employees" },

    { 
        "$lookup": {
            "from": "Customers",
            "localField": "Employees.employeeNumber",
            "foreignField": "salesRepEmployeeNumber",
            "as": "Clients"
        }
    },

    { 
        "$addFields": { 
            "nombreClients": { "$size": "$Clients" },
            "totalCommandes": { 
                "$sum": { 
                    "$map": { 
                        "input": "$Clients", 
                        "as": "client", 
                        "in": { 
                            "$size": { "$ifNull": [ "$$client.Orders", [] ] }
                        } 
                    } 
                }
            },
        }
    },

    { "$unwind": {
        "path": "$Clients",
        "preserveNullAndEmptyArrays": True
    }},
    
    { "$unwind": {
        "path": "$Clients.Orders",
        "preserveNullAndEmptyArrays": True
    }},
    
    { "$unwind": {
        "path": "$Clients.Payments",
        "preserveNullAndEmptyArrays": True
    }},
    
    { 
        "$group": { 
            "_id": "$Employees.employeeNumber",
            "prenom": { "$first": "$Employees.firstName" },  
            "nom": { "$first": "$Employees.lastName" },     
            "nombreClients": { "$first": "$nombreClients" }, 
            "totalCommandes": { "$first": "$totalCommandes" }, 
            "totalPayments": { "$sum": "$Clients.Payments.amount" }  
        }
    },
    {
        "$project": {
            "_id": 0,
            "employeeNumber": "$_id",
            "firstname": "$prenom",
            "lastname": "$nom",
            "numberOfCustomers": "$nombreClients",
            "numberOfOrders": "$totalCommandes",
            "totalOrderAmount": {
                "$cond": {
                    "if": { "$eq": ["$totalPayments", 0] },
                    "then": "NaN",
                    "else": "$totalPayments"
                }
            }
        }
    },

    { "$sort": { "employeeNumber": 1 }}
])

rq2_df = pandas.DataFrame(list(rq2))
rq2_df


# Pour chaque employé on a son nombre de clients, commandes et le montant total.
# On voit que Diane, Mary et Jeff n'ont pas réalisé de commande et
# donc ont un montant total de null (NaN)
# Out:
#     employeeNumber firstname   lastname  numberOfCustomers  numberOfOrders  \
# 0             1002     Diane     Murphy                  0               0
# 1             1056      Mary  Patterson                  0               0
# 2             1076      Jeff   Firrelli                  0               0
# 3             1088   William  Patterson                  0               0
# 4             1102    Gerard     Bondur                  0               0
# 5             1143   Anthony        Bow                  0               0
# 6             1165    Leslie   Jennings                 12              68
# 7             1166    Leslie   Thompson                 12              28
# 8             1188     Julie   Firrelli                 12              28
# 9             1216     Steve  Patterson                 12              36
# 10            1286  Foon Yue      Tseng                 14              34
# 11            1323    George     Vanauf                 16              44
# 12            1337      Loui     Bondur                 12              40
# 13            1370    Gerard  Hernandez                 14              86
# 14            1401    Pamela   Castillo                 20              62
# 15            1501     Larry       Bott                 16              44
# 16            1504     Barry      Jones                 18              50
# 17            1611      Andy     Fixter                 10              38
# 18            1612     Peter      Marsh                 10              38
# 19            1619       Tom       King                  0               0
# 20            1621      Mami      Nishi                 10              32
# 21            1625   Yoshimi       Kato                  0               0
# 22            1702    Martin     Gerard                 12              24
#
#    totalOrderAmount
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6       50696264.52
# 7        3773769.92
# 8        4140175.96
# 9        6183960.32
# 10        6540906.4
# 11        7483734.2
# 12       8373118.04
# 13      87402973.56
# 14       10322202.2
# 15        8754875.2
# 16       9429479.48
# 17       9409015.36
# 18       8478806.88
# 19              NaN
# 20       7261852.68
# 21              NaN
# 22       4057756.56

# %%
rq3 = db.Offices.aggregate([
    { 
        "$lookup": {
            "from": "Customers",
            "localField": "Employees.employeeNumber",
            "foreignField": "salesRepEmployeeNumber",
            "as": "Clients"
        }
    },
    {
        "$addFields": { 
            "nombreClients": { "$size": "$Clients" },
            "totalCommandes": { 
                "$sum": { 
                    "$map": { 
                        "input": "$Clients", 
                        "as": "client", 
                        "in": { "$size": { "$ifNull": [ "$$client.Orders", [] ] } }
                    } 
                }
            },
            "clientsFromDifferentCountries": {
                "$size": {
                    "$filter": {
                        "input": "$Clients",
                        "as": "client",
                        "cond": { "$ne": ["$$client.country", "$country"] }
                    }
                }
            }
        }
    },

    { "$unwind": {
        "path": "$Clients",
        "preserveNullAndEmptyArrays": True
    }},
    
    { "$unwind": {
        "path": "$Clients.Orders",
        "preserveNullAndEmptyArrays": True
    }},
    
    { "$unwind": {
        "path": "$Clients.Payments",
        "preserveNullAndEmptyArrays": True
    }},
    
    { 
        "$group": { 
            "_id": "$officeCode",
            "nombreClients": { "$first": "$nombreClients" },  
            "totalCommandes": { "$first": "$totalCommandes" }, 
            "totalPayments": { "$sum": "$Clients.Payments.amount" }, 
            "nombrePaysDistincts": {"$first": "$clientsFromDifferentCountries"},
            "pays": {"$first": "$country"},
            "ville": {"$first": "$city"}
        }
    },

    {
        "$project": {
            "_id": 0,
            "officeCode": "$_id",
            "city": "$ville",
            "country": "$pays",
            "numberOfCustomers": "$nombreClients",
            "numberOfOrders": "$totalCommandes",
            "totalOrderAmount": {
                "$cond": {
                    "if": { "$eq": ["$totalPayments", 0] },
                    "then": "nan",
                    "else": "$totalPayments"
                }
            },
            "customersFromDifferentCountry": "$nombrePaysDistincts"
        }
    },

    { "$sort": { "officeCode": 1 }}
])

rq3_df = pandas.DataFrame(list(rq3))
rq3_df


# On donne le nombre de commandes, montant total et nombre de clients venant d'un pays différent pour chaque bureau.
#On voit que San Francisco
# a 12 clients, 48 commandes un montant total de plus de 13 millions et 0 clients étrangés.
# Out:
#   officeCode           city    country  numberOfCustomers  numberOfOrders  \
# 0        1.0  San Francisco        USA                 24              96
# 1        2.0         Boston        USA                 24              64
# 2        3.0            NYC        USA                 30              78
# 3        4.0          Paris     France                 58             212
# 4        5.0          Tokyo      Japan                 10              32
# 5        6.0         Sydney  Australia                 20              76
# 6        7.0         London         UK                 34              94
#
#    totalOrderAmount  customersFromDifferentCountry
# 0      5.447003e+07                              0
# 1      1.032414e+07                              0
# 2      1.402464e+07                              6
# 3      1.101561e+08                             34
# 4      7.261853e+06                              6
# 5      1.788782e+07                             10
# 6      1.818435e+07                             24

# %%
rq4 = db.Products.aggregate([
    {
        "$lookup": {
            "from": "Customers",
            "localField": "productCode",
            "foreignField": "Orders.OrderDetails.productCode",
            "as": "customerOrders"
        }
    },
    {
        "$unwind": {
            "path": "$customerOrders",
            "preserveNullAndEmptyArrays": True
        }
    },
    {
        "$unwind": {
            "path": "$customerOrders.Orders",
            "preserveNullAndEmptyArrays": True
        }
    },
    {
        "$unwind": {
            "path": "$customerOrders.Orders.OrderDetails",
            "preserveNullAndEmptyArrays": True
        }
    },
    {
        "$match": {
            "$or": [
                { "$expr": { "$eq": ["$customerOrders.Orders.OrderDetails.productCode", "$productCode"] } },
                { "customerOrders": { "$eq": None } }
            ]
        }
    },
    {
        "$group": {
            "_id": "$productCode",
            "nomProduit": { "$first": "$productName" },
            "totalOccurrences": { "$sum": { "$cond": [{ "$ifNull": ["$customerOrders", False] }, 1, 0] } },
            "totalQuantity": { "$sum": { "$ifNull": ["$customerOrders.Orders.OrderDetails.quantityOrdered", 0] } },
            "uniqueClients": { "$addToSet": "$customerOrders.customerNumber" }
        }
    },
    {
        "$addFields": {
            "nombreClientDistincs": { "$size": "$uniqueClients" }
        }
    },
    {
        "$sort": { "_id": 1 }
    },
    {
        "$project": {
            "_id": 1,
            "nomProduit": 1,
            "totalOccurrences": 1,
            "totalQuantity": 1,
            "nombreClientDistincs": 1
        }
    }
])

rq4_df = pandas.DataFrame(list(rq4))
rq4_df

# Pour chaque produit on donne le nombre de fois où il a été commandé, la quantité total commandée et 
#le nombre distinct de client qui a commandé
# le produit. Par exemple le modèle 1969 Harley Davidson Ultimate Chopper se retrouve dans 28 commandes,
#il a été commandé 1026 par 26 clients différents
# Out:
#            _id                             nomProduit  totalOccurrences  \
# 0     S10_1678  1969 Harley Davidson Ultimate Chopper               112
# 1     S10_1949               1952 Alpine Renault 1300               112
# 2     S10_2016                  1996 Moto Guzzi 1100i               112
# 3     S10_4698   2003 Harley-Davidson Eagle Drag Bike               112
# 4     S10_4757                    1972 Alfa Romeo GTA               112
# ..         ...                                    ...               ...
# 105  S700_3505                            The Titanic               108
# 106  S700_3962                         The Queen Mary               108
# 107  S700_4002              American Airlines: MD-11S               112
# 108   S72_1253                       Boeing X-32A JSF               112
# 109   S72_3212                             Pont Yacht               108
#
#      totalQuantity  nombreClientDistincs
# 0             4104                    26
# 1             3844                    27
# 2             3996                    26
# 3             3940                    25
# 4             4000                    27
# ..             ...                   ...
# 105           3808                    22
# 106           3532                    24
# 107           4292                    26
# 108           3840                    27
# 109           3832                    24
#
# [110 rows x 5 columns]

# %%
rq5 = db.Customers.aggregate([
    {
        "$lookup": {
            "from": "Customers",
            "localField": "_id",
            "foreignField": "_id",
            "as": "Commandes"
        }
    },
    { 
        "$unwind": { 
            "path": "$Orders", 
            "preserveNullAndEmptyArrays": True 
        }
    },
    {
        "$addFields": {
            "montantCommande": {
                "$cond": {
                    "if": { "$gt": ["$Orders", None] },
                    "then": {
                        "$sum": {
                            "$map": {
                                "input": { "$ifNull": ["$Orders.OrderDetails", []] },
                                "as": "item",
                                "in": { "$multiply": ["$$item.quantityOrdered", "$$item.priceEach"] }
                            }
                        }
                    },
                    "else": 0
                }
            },
            "montantPaye": { "$sum": "$Payments.amount" },
            "nombreCommande": { "$cond": { "if": { "$gt": ["$Orders", None] }, "then": 1, "else": 0 } }
        }
    },
    {
        "$group": {
            "_id": "$country",
            "Nombre de Commande": { "$sum": "$nombreCommande" },  
            "Montant Total Commande": { "$sum": "$montantCommande"},
            "Montant Total Payé": {"$sum":"$montantPaye"}
        }
    },
    { "$sort": { "_id": 1 } }
])

pandas.DataFrame(list(rq5))
#Pour chaque pays on affiche le nombre de commandes, le montant total commandé et le montant total payé
#Par exemple, il y a eu 7 commandes au Canada pour un montant total de 224 078€ dont 421 283€ ont été payés
# Out:
#              _id  Nombre de Commande  Montant Total Commande  \
# 0      Australia                  38              1261246.20
# 1        Austria                  14               404125.06
# 2        Belgium                  14               216825.24
# 3         Canada                  14               448157.12
# 4        Denmark                  14               491274.30
# 5        Finland                  18               659163.82
# 6         France                  74              2221833.12
# 7        Germany                  14               440944.18
# 8      Hong Kong                   4                97568.72
# 9        Ireland                   4               115512.86
# 10        Israel                   0                    0.00
# 11         Italy                  20               807252.44
# 12         Japan                  12               376335.62
# 13   Netherlands                   0                    0.00
# 14   New Zealand                  30              1071168.00
# 15        Norway                  18               614927.40
# 16   Philippines                   6               188031.46
# 17        Poland                   0                    0.00
# 18      Portugal                   0                    0.00
# 19        Russia                   0                    0.00
# 20     Singapore                  18               576976.82
# 21  South Africa                   0                    0.00
# 22         Spain                  72              2431373.84
# 23        Sweden                  14               420028.42
# 24   Switzerland                   4               235427.12
# 25            UK                  26               957760.92
# 26           USA                 224              7255965.70
#
#     Montant Total Payé
# 0           4704507.68
# 1            974988.04
# 2            666884.22
# 3            842566.00
# 4           1592669.50
# 5           1977491.46
# 6           6649387.04
# 7           1152586.88
# 8            195137.44
# 9            231025.72
# 10                0.00
# 11          1926559.34
# 12          1141797.72
# 13                0.00
# 14          3336114.24
# 15          1919532.12
# 16           564094.38
# 17                0.00
# 18                0.00
# 19                0.00
# 20          2633186.00
# 21                0.00
# 22         42796682.80
# 23          1411595.02
# 24           470854.24
# 25          2399946.14
# 26         38566839.66

# %%
rq6 = db.Customers.aggregate([
    {
        "$unwind": "$Orders" 
    },
    {
        "$unwind": "$Orders.OrderDetails" 
    },
    { 
        "$lookup": {
            "from": "Products",  
            "localField": "Orders.OrderDetails.productCode",  
            "foreignField": "productCode", 
            "as": "productDetails" 
        }
    },
    {
        "$unwind": {
            "path": "$productDetails", 
            "preserveNullAndEmptyArrays": True 
        }
    },
    {
        "$group": {
            "_id": {
                "orderNumber": "$Orders.orderNumber",  
                "country": "$country",  
                "productLine": "$productDetails.productLine"  
            },
            "customerName": { "$first": "$customerName" }  
        }
    },
    {
        "$group": {
            "_id": {
                "productLine": "$_id.productLine",  
                "country": "$_id.country"  
            },
            "totalOrders": { "$sum": 1 }  
        }
    },
    {
        "$project": {
            "_id": 0,
            "productLine": "$_id.productLine", 
            "country": "$_id.country",  
            "totalOrders": 1  
        }
    },
    {
        "$sort": {
            "productLine": 1,
            "country": 1
        }
    }
])


result_df = pandas.DataFrame(list(rq6))
result_df = result_df[['productLine', 'country', 'totalOrders']]
print(result_df)

# Pour chaque pays et chaque catégorie on a le total des commandes.
#Par exemple, on a l'Australie qui a commandé 12 produits de la catégorie Classic Cars.
# Out:
#       productLine    country  totalOrders
# 0    Classic Cars  Australia           12
# 1    Classic Cars    Austria            5
# 2    Classic Cars    Belgium            2
# 3    Classic Cars     Canada            6
# 4    Classic Cars    Denmark            5
# ..            ...        ...          ...
# 121  Vintage Cars  Singapore            4
# 122  Vintage Cars      Spain           22
# 123  Vintage Cars     Sweden            4
# 124  Vintage Cars         UK           10
# 125  Vintage Cars        USA           67
#
# [126 rows x 3 columns]

# %%
rq7 = db.Customers.aggregate([
    {
        "$unwind": "$Orders"
    },
    {
        "$unwind": "$Orders.OrderDetails"
    },
    {
        "$lookup": {
            "from": "Products",
            "localField": "Orders.OrderDetails.productCode",
            "foreignField": "productCode",
            "as": "ProductInfo"
        }
    },
    {
        "$unwind": "$ProductInfo"
    },
    {
        "$group": {
            "_id": {
                "country": "$country",
                "productLine": "$ProductInfo.productLine"
            },
            "totalPayments": {"$sum": {"$sum": "$Payments.amount"}}
        }
    },
    {
        "$project": {
            "_id": 0,
            "country": "$_id.country",
            "productLine": "$_id.productLine",
            "totalPayments": 1
        }
    },
    {
        "$sort": {
            "productLine": 1,
            "country": 1
        }
    },
])

results_df = pandas.DataFrame(list(rq7))
results_df = results_df[['productLine', 'country', 'totalPayments']]
results_df

#Pour chaque types de produit et chaques pays, on prend le total payé. Par exemple, pour les classic cars en autralie,
#30019180€
# Out:
#       productLine    country  totalPayments
# 0    Classic Cars  Australia   3.001918e+07
# 1    Classic Cars    Austria   7.537678e+06
# 2    Classic Cars    Belgium   6.675235e+05
# 3    Classic Cars     Canada   3.099696e+06
# 4    Classic Cars    Denmark   1.471325e+07
# ..            ...        ...            ...
# 121  Vintage Cars  Singapore   7.764909e+06
# 122  Vintage Cars      Spain   1.595140e+08
# 123  Vintage Cars     Sweden   5.508377e+06
# 124  Vintage Cars         UK   1.869265e+07
# 125  Vintage Cars        USA   1.883629e+08
#
# [126 rows x 3 columns]

# %%
rq8 = db.Products.aggregate([
    {
        "$lookup": {
            "from": "Customers",
            "localField": "productCode",
            "foreignField": "Orders.OrderDetails.productCode",
            "as": "detailCommande"
        }
    },
    {
        "$unwind": "$detailCommande" 
    },
    {
        "$unwind": "$detailCommande.Orders"  
    },
    {
        "$unwind": "$detailCommande.Orders.OrderDetails" 
    },
    {
        "$match": {
            "$expr": { "$eq": ["$productCode", "$detailCommande.Orders.OrderDetails.productCode"] }
        }
    },
    {
        "$project": {
            "productCode": "$productCode",
            "productName": "$productName",
            "marge": {
                "$subtract": ["$detailCommande.Orders.OrderDetails.priceEach", "$buyPrice"]
            }  
        }
    },
    {
        "$group": {
            "_id": {
                "productCode": "$productCode",
                "productName": "$productName"
            },
            "averageMargin": {"$avg": "$marge"} 
        }
    },
    {
        "$project": {
            "_id": 0,
            "productCode": "$_id.productCode",
            "productName": "$_id.productName",
            "averageMargin": 1
        }
    },
    {
        "$sort": {
            "averageMargin": -1 
        }
    },
    {
        "$limit": 10
    }
])


result_df = pandas.DataFrame(list(rq8))
result_df = result_df[['productCode', 'productName', 'averageMargin']] 
result_df


# Pour chaque produit on a la marge moyenne du produit. Par exemple, pour le modèle 1952 Alpine Renault 1300 la marge moyenne du produit est de 99.006429.
# Out:
#   productCode                           productName  averageMargin
# 0    S10_1949              1952 Alpine Renault 1300      99.006429
# 1    S10_4698  2003 Harley-Davidson Eagle Drag Bike      95.235000
# 2    S18_3232           1992 Ferrari 360 Spider red      83.334906
# 3    S12_2823                      2002 Suzuki XREO      83.201429
# 4    S18_2795                1928 Mercedes-Benz SSK      82.696786
# 5    S12_1108                     2001 Ferrari Enzo      81.043704
# 6    S12_3891                      1969 Ford Falcon      77.335926
# 7    S18_3685        1948 Porsche Type 356 Roadster      72.636800
# 8    S18_2870          1999 Indy 500 Monte Carlo SS      71.794400
# 9    S18_1749              1917 Grand Touring Sedan      70.432800

# %%
rq9 = db.Customers.aggregate([
    {
        '$unwind': '$Orders'
    },
    {
        '$unwind': '$Orders.OrderDetails'
    },
    {
        '$lookup': {
            'from': 'Products',
            'localField': 'Orders.OrderDetails.productCode',
            'foreignField': 'productCode',
            'as': 'product_info'
        }
    },
    {
        '$unwind': '$product_info'
    },
    {
        '$project': {
            '_id': 0,
            'customerNumber': 1,
            'productCode': '$Orders.OrderDetails.productCode',
            'productName': '$product_info.productName',
            'priceEach': '$Orders.OrderDetails.priceEach',
            'buyPrice': '$product_info.buyPrice'
        }
    },
    {
        '$match': {
            '$expr': { 
                '$lt': ['$priceEach', '$buyPrice']
            }
        }
    }
])

results_df = pandas.DataFrame(list(rq9))
results_df

# On veut les produits vendu à perte (prix unitaire < prix d'achat). On voit que le modèle 1957 Chevy Pickup a un prix unitaire de 35.71 et le prix
# d'achat est de 55.70.
# Out:
#      customerNumber productCode                        productName  priceEach  \
# 0               124    S12_4473                  1957 Chevy Pickup      35.71
# 1               124    S12_4473                  1957 Chevy Pickup      35.71
# 2               124    S24_4048  1992 Porsche Cayenne Turbo Silver      50.32
# 3               124    S24_4048  1992 Porsche Cayenne Turbo Silver      50.32
# 4               124    S50_1392   Diamond T620 Semi-Skirted Tanker      56.55
# ..              ...         ...                                ...        ...
# 311             486    S18_1749           1917 Grand Touring Sedan      74.04
# 312             486    S18_1984                   1995 Honda Civic      32.47
# 313             486    S18_1984                   1995 Honda Civic      32.47
# 314             496    S18_1662        1980s Black Hawk Helicopter      58.67
# 315             496    S18_1662        1980s Black Hawk Helicopter      58.67
#
#      buyPrice
# 0       55.70
# 1       55.70
# 2       69.78
# 3       69.78
# 4       68.29
# ..        ...
# 311     86.70
# 312     93.89
# 313     93.89
# 314     77.27
# 315     77.27
#
# [316 rows x 5 columns]

# %%
rq10 = db.Customers.aggregate([
    {
        "$addFields": {
            "montantPaye": { "$sum": "$Payments.amount" }  
        }
    },
    { 
        "$unwind": "$Orders"
    },
    {
        "$unwind": "$Orders.OrderDetails"
    },
    {
        "$addFields": {
            "montantCommande": { "$multiply": [
                "$Orders.OrderDetails.quantityOrdered",
                "$Orders.OrderDetails.priceEach"
            ] }
        }
    },
    {
        "$group": {
            "_id": "$customerNumber",
            "codeClient": { "$first": "$customerNumber" },
            "nomClient": { "$first": "$customerName" },
            "Montant Total Payé": { "$first": "$montantPaye" },
            "Montant Total Commande": { "$sum": "$montantCommande" }
        }
    },
    {
        "$match": {
            "$expr": { "$gt": [ "$Montant Total Payé", "$Montant Total Commande" ] }  
        }
    }
])
result_df = pandas.DataFrame(list(rq10))
result_df

# On a la liste des clients avec un montant des paiements supérieur a celui des achats, comme Toys4GrownUps.com
# Out:
# Empty DataFrame
# Columns: []
# Index: []
